# %% [markdown]
# # What is RAG
#
# Retrieval-Augmented Generation (RAG) is a technique used in natural language processing (NLP) that enhances the capabilities of large language models (LLMs) by incorporating external knowledge sources. Instead of solely relying on the information stored within their parameters, LLMs using RAG retrieve relevant information from external databases or documents to generate more comprehensive and accurate responses. This approach enables LLMs to access and process real-time information, domain-specific knowledge, and factual data that may not be present in their training data, thereby improving their overall performance and accuracy.
#
# # What is a Vector Database
#
# Vector Databases are specialized databases designed to efficiently store and retrieve high-dimensional vectors, often used as representations of data like text, images, or audio. These databases utilize similarity search algorithms to quickly identify vectors that are most similar to a given query vector. In the context of RAG, vector databases are used to store and retrieve the embeddings of external knowledge sources, allowing LLMs to quickly locate relevant information based on the semantic similarity of their queries.
#
# # How they are related
#
# Relationship between RAG and Vector Databases: In RAG, vector databases serve as the knowledge source, storing information in the form of embeddings. When an LLM receives a query, it generates an embedding for the query and uses it to search the vector database for similar embeddings representing relevant information. The retrieved information is then used by the LLM to augment its response, making it more comprehensive and accurate.
#
#  **Note**: If you are seeing this notebook in GitHub or in a non-colab server, press the following button to run it in Colab [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DNALinux/ai/blob/main/notebooks/DNALinux_RAG.ipynb)

# %% [markdown]
# # Preparation work (install dependencies)

# %%
# !apt install pciutils lshw
# !curl -fsSL https://ollama.com/install.sh | sh
# !git clone https://github.com/DNALinux/ai.git

# !wget https://github.com/conda-forge/miniforge/releases/download/25.3.0-2/Miniforge3-Linux-x86_64.sh
# !chmod +x Miniforge3-Linux-x86_64.sh
# !./Miniforge3-Linux-x86_64.sh -b -p miniforge3
# !miniforge3/bin/mamba env create -f ai/environment.yml -y
# !mkdir -p /content/testdata1/
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloading       100%
# Extracting  (194)  ⣾  [+] 1m:43.2s
# Downloading       100%
# Extracting  (194)  ⣾  [+] 1m:43.3s
# Downloading       100%
# Extracting  (194)  ⣾  [+] 1m:43.4s
# Downloading       100%
# Extracting  (194)  ⣾  [+] 1m:43.5s
# Downloading       100%
# Extracting  (193)  ⣾  [+] 1m:43.6s
# Downloading       100%
# Extracting  (192)  ⣾  [+] 1m:43.7s
# Downloading       100%
# Extracting  (192)  ⣾  [+] 1m:43.8s
# Downloading       100%
# Extracting  (191)  ⣾  [+] 1m:43.9s
# Downloading       100%
# Extracting  (190)  ⣾  [+] 1m:44.0s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.1s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.2s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.3s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.4s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.5s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.6s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.7s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.8s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:44.9s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.0s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.1s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.2s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.3s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.4s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.5s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.6s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.7s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.8s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:45.9s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.0s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.1s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.2s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.3s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.4s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.5s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.6s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.7s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.8s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:46.9s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.0s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.1s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.2s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.3s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.4s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.5s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.6s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.7s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.8s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:47.9s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.0s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.1s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.2s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.3s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.4s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.5s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.6s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.7s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.8s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:48.9s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.0s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.1s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.2s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.3s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.4s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.5s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.6s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.7s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.8s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:49.9s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:50.0s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:50.1s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:50.2s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:50.3s
# Downloading       100%
# Extracting  (189)  ⣾  [+] 1m:50.4s
# Downloading       100%
# Extracting  (188)  ⣾  [+] 1m:50.5s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:50.6s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:50.7s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:50.8s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:50.9s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.0s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.1s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.2s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.3s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.4s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.5s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.6s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.7s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.8s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:51.9s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.0s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.1s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.2s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.3s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.4s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.5s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.6s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.7s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.8s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:52.9s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.0s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.1s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.2s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.3s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.4s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.5s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.6s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.7s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.8s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:53.9s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.0s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.1s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.2s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.3s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.4s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.5s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.6s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.7s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.8s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:54.9s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.0s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.1s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.2s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.3s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.4s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.5s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.6s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.7s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.8s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:55.9s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.0s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.1s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.2s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.3s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.4s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.5s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.6s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.7s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.8s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:56.9s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:57.0s
# Downloading       100%
# Extracting  (187)  ⣾  [+] 1m:57.1s
# Downloading       100%
# Extracting  (186)  ⣾  [+] 1m:57.2s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:57.3s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:57.4s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:57.5s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:57.6s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:57.7s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:57.8s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:57.9s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.0s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.1s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.2s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.3s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.4s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.5s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.6s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.7s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.8s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:58.9s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.0s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.1s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.2s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.3s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.4s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.5s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.6s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.7s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.8s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 1m:59.9s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.0s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.1s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.2s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.3s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.4s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.5s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.6s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.7s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.8s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:0.9s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.0s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.1s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.2s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.3s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.4s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.5s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.6s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.7s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.8s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:1.9s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:2.0s
# Downloading       100%
# Extracting  (185)  ⣾  [+] 2m:2.1s
# Downloading       100%
# Extracting  (184)  ⣾  [+] 2m:2.2s
# Downloading       100%
# Extracting  (184)  ⣾  [+] 2m:2.3s
# Downloading       100%
# Extracting  (183)  ⣾  [+] 2m:2.4s
# Downloading       100%
# Extracting  (181)  ⣾  [+] 2m:2.5s
# Downloading       100%
# Extracting  (180)  ⣾  [+] 2m:2.6s
# Downloading       100%
# Extracting  (180)  ⣾  [+] 2m:2.7s
# Downloading       100%
# Extracting  (180)  ⣾  [+] 2m:2.8s
# Downloading       100%
# Extracting  (178)  ⣾  [+] 2m:2.9s
# Downloading       100%
# Extracting  (177)  ⣾  [+] 2m:3.0s
# Downloading       100%
# Extracting  (175)  ⣾  [+] 2m:3.1s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:3.2s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:3.3s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:3.4s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:3.5s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:3.6s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:3.7s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:3.8s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:3.9s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:4.0s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:4.1s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:4.2s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 2m:4.3s
# Downloading       100%
# Extracting  (173)  ⣾  [+] 2m:4.4s
# Downloading       100%
# Extracting  (172)  ⣾  [+] 2m:4.5s
# Downloading       100%
# Extracting  (171)  ⣾  [+] 2m:4.6s
# Downloading       100%
# Extracting  (169)  ⣾  [+] 2m:4.7s
# Downloading       100%
# Extracting  (169)  ⣾  [+] 2m:4.8s
# Downloading       100%
# Extracting  (167)  ⣾  [+] 2m:4.9s
# Downloading       100%
# Extracting  (167)  ⣾  [+] 2m:5.0s
# Downloading       100%
# Extracting  (167)  ⣾  [+] 2m:5.1s
# Downloading       100%
# Extracting  (166)  ⣾  [+] 2m:5.2s
# Downloading       100%
# Extracting  (162)  ⣾  [+] 2m:5.3s
# Downloading       100%
# Extracting  (162)  ⣾  [+] 2m:5.4s
# Downloading       100%
# Extracting  (161)  ⣾  [+] 2m:5.5s
# Downloading       100%
# Extracting  (161)  ⣾  [+] 2m:5.6s
# Downloading       100%
# Extracting  (161)  ⣾  [+] 2m:5.7s
# Downloading       100%
# Extracting  (161)  ⣾  [+] 2m:5.8s
# Downloading       100%
# Extracting  (161)  ⣾  [+] 2m:5.9s
# Downloading       100%
# Extracting  (161)  ⣾  [+] 2m:6.0s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.1s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.2s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.3s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.4s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.5s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.6s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.7s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.8s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:6.9s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.0s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.1s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.2s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.3s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.4s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.5s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.6s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.7s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.8s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:7.9s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:8.0s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:8.1s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:8.2s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:8.3s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:8.4s
# Downloading       100%
# Extracting  (159)  ⣾  [+] 2m:8.5s
# Downloading       100%
# Extracting  (158)  ⣾  [+] 2m:8.6s
# Downloading       100%
# Extracting  (156)  ⣾  [+] 2m:8.7s
# Downloading       100%
# Extracting  (154)  ⣾  [+] 2m:8.8s
# Downloading       100%
# Extracting  (154)  ⣾  [+] 2m:8.9s
# Downloading       100%
# Extracting  (153)  ⣾  [+] 2m:9.0s
# Downloading       100%
# Extracting  (152)  ⣾  [+] 2m:9.1s
# Downloading       100%
# Extracting  (150)  ⣾  [+] 2m:9.2s
# Downloading       100%
# Extracting  (149)  ⣾  [+] 2m:9.3s
# Downloading       100%
# Extracting  (147)  ⣾  [+] 2m:9.4s
# Downloading       100%
# Extracting  (145)  ⣾  [+] 2m:9.5s
# Downloading       100%
# Extracting  (145)  ⣾  [+] 2m:9.6s
# Downloading       100%
# Extracting  (145)  ⣾  [+] 2m:9.7s
# Downloading       100%
# Extracting  (145)  ⣾  [+] 2m:9.8s
# Downloading       100%
# Extracting  (144)  ⣾  [+] 2m:9.9s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.0s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.1s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.2s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.3s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.4s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.5s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.6s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.7s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.8s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:10.9s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:11.0s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:11.1s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:11.2s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:11.3s
# Downloading       100%
# Extracting  (143)  ⣾  [+] 2m:11.4s
# Downloading       100%
# Extracting  (142)  ⣾  [+] 2m:11.5s
# Downloading       100%
# Extracting  (142)  ⣾  [+] 2m:11.6s
# Downloading       100%
# Extracting  (142)  ⣾  [+] 2m:11.7s
# Downloading       100%
# Extracting  (142)  ⣾  [+] 2m:11.8s
# Downloading       100%
# Extracting  (141)  ⣾  [+] 2m:11.9s
# Downloading       100%
# Extracting  (140)  ⣾  [+] 2m:12.0s
# Downloading       100%
# Extracting  (140)  ⣾  [+] 2m:12.1s
# Downloading       100%
# Extracting  (139)  ⣾  [+] 2m:12.2s
# Downloading       100%
# Extracting  (139)  ⣾  [+] 2m:12.3s
# Downloading       100%
# Extracting  (138)  ⣾  [+] 2m:12.4s
# Downloading       100%
# Extracting  (138)  ⣾  [+] 2m:12.5s
# Downloading       100%
# Extracting  (138)  ⣾  [+] 2m:12.6s
# Downloading       100%
# Extracting  (138)  ⣾  [+] 2m:12.7s
# Downloading       100%
# Extracting  (138)  ⣾  [+] 2m:12.8s
# Downloading       100%
# Extracting  (138)  ⣾  [+] 2m:12.9s
# Downloading       100%
# Extracting  (138)  ⣾  [+] 2m:13.0s
# Downloading       100%
# Extracting  (137)  ⣾  [+] 2m:13.1s
# Downloading       100%
# Extracting  (135)  ⣾  [+] 2m:13.2s
# Downloading       100%
# Extracting  (134)  ⣾  [+] 2m:13.3s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:13.4s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:13.5s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:13.6s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:13.7s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:13.8s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:13.9s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.0s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.1s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.2s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.3s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.4s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.5s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.6s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.7s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.8s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:14.9s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.0s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.1s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.2s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.3s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.4s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.5s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.6s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.7s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.8s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:15.9s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:16.0s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:16.1s
# Downloading       100%
# Extracting  (133)  ⣾  [+] 2m:16.2s
# Downloading       100%
# Extracting  (132)  ⣾  [+] 2m:16.3s
# Downloading       100%
# Extracting  (131)  ⣾  [+] 2m:16.4s
# Downloading       100%
# Extracting  (130)  ⣾  [+] 2m:16.5s
# Downloading       100%
# Extracting  (129)  ⣾  [+] 2m:16.6s
# Downloading       100%
# Extracting  (128)  ⣾  [+] 2m:16.7s
# Downloading       100%
# Extracting  (127)  ⣾  [+] 2m:16.8s
# Downloading       100%
# Extracting  (127)  ⣾  [+] 2m:16.9s
# Downloading       100%
# Extracting  (126)  ⣾  [+] 2m:17.0s
# Downloading       100%
# Extracting  (126)  ⣾  [+] 2m:17.1s
# Downloading       100%
# Extracting  (124)  ⣾  [+] 2m:17.2s
# Downloading       100%
# Extracting  (124)  ⣾  [+] 2m:17.3s
# Downloading       100%
# Extracting  (124)  ⣾  [+] 2m:17.4s
# Downloading       100%
# Extracting  (123)  ⣾  [+] 2m:17.5s
# Downloading       100%
# Extracting  (122)  ⣾  [+] 2m:17.6s
# Downloading       100%
# Extracting  (122)  ⣾  [+] 2m:17.7s
# Downloading       100%
# Extracting  (121)  ⣾  [+] 2m:17.8s
# Downloading       100%
# Extracting  (120)  ⣾  [+] 2m:17.9s
# Downloading       100%
# Extracting  (119)  ⣾  [+] 2m:18.0s
# Downloading       100%
# Extracting  (118)  ⣾  [+] 2m:18.1s
# Downloading       100%
# Extracting  (117)  ⣾  [+] 2m:18.2s
# Downloading       100%
# Extracting  (117)  ⣾  [+] 2m:18.3s
# Downloading       100%
# Extracting  (115)  ⣾  [+] 2m:18.4s
# Downloading       100%
# Extracting  (113)  ⣾  [+] 2m:18.5s
# Downloading       100%
# Extracting  (112)  ⣾  [+] 2m:18.6s
# Downloading       100%
# Extracting  (112)  ⣾  [+] 2m:18.7s
# Downloading       100%
# Extracting  (112)  ⣾  [+] 2m:18.8s
# Downloading       100%
# Extracting  (110)  ⣾  [+] 2m:18.9s
# Downloading       100%
# Extracting  (109)  ⣾  [+] 2m:19.0s
# Downloading       100%
# Extracting  (108)  ⣾  [+] 2m:19.1s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:19.2s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:19.3s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:19.4s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:19.5s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:19.6s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:19.7s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:19.8s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:19.9s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:20.0s
# Downloading       100%
# Extracting  (107)  ⣾  [+] 2m:20.1s
# Downloading       100%
# Extracting  (106)  ⣾  [+] 2m:20.2s
# Downloading       100%
# Extracting  (105)  ⣾  [+] 2m:20.3s
# Downloading       100%
# Extracting  (105)  ⣾  [+] 2m:20.4s
# Downloading       100%
# Extracting  (105)  ⣾  [+] 2m:20.5s
# Downloading       100%
# Extracting  (103)  ⣾  [+] 2m:20.6s
# Downloading       100%
# Extracting  (102)  ⣾  [+] 2m:20.7s
# Downloading       100%
# Extracting  (100)  ⣾  [+] 2m:20.8s
# Downloading      100%
# Extracting  (99)  ⣾  [+] 2m:20.9s
# Downloading      100%
# Extracting  (98)  ⣾  [+] 2m:21.0s
# Downloading      100%
# Extracting  (98)  ⣾  [+] 2m:21.1s
# Downloading      100%
# Extracting  (97)  ⣾  [+] 2m:21.2s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2m:21.3s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2m:21.4s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2m:21.5s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2m:21.6s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2m:21.7s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2m:21.8s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2m:21.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:22.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:23.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:24.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:25.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:26.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:27.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:28.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:29.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:30.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:31.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:32.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:33.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:34.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:35.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:36.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:37.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:38.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:39.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:40.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:41.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:42.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:43.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:44.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:45.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:46.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:47.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:48.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:49.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:50.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:51.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:52.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:53.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:54.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:55.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:56.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:57.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:58.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2m:59.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:0.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:1.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:2.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:3.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:4.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:5.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.8s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:6.9s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:7.0s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:7.1s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:7.2s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:7.3s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:7.4s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:7.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 3m:7.6s
# Downloading      100%
# ...
# Extracting   (1)  ⣾  [+] 5m:32.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:32.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:32.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:32.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:33.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:34.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:35.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:36.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:37.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:38.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:38.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5m:38.2s
# Downloading      100%
# Extracting   (1)  ⣾  Linking _libgcc_mutex-0.1-conda_forge
# Linking ca-certificates-2024.7.4-hbcca054_0
# Linking libgomp-14.1.0-h77fa898_0
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-ng-14.1.0-h77fa898_0
# Linking selenium-manager-4.22.0-he9194b0_0
# Linking openssl-3.3.1-h4ab18f5_1
# Linking libstdcxx-ng-14.1.0-hc0a3c3a_0
# Linking libsodium-1.0.18-h36c2ea0_1
# Linking cuda-cudart-12.1.105-0
# Linking cuda-cupti-12.1.105-0
# Linking cuda-nvrtc-12.1.105-0
# Linking cuda-nvtx-12.1.105-0
# Linking libcublas-12.1.0.26-0
# Linking libcufft-11.0.2.4-0
# Linking libcusolver-11.4.4.55-0
# Linking libcusparse-12.0.2.55-0
# Linking libnpp-12.0.2.50-0
# Linking libnvjitlink-12.1.105-0
# Linking libnvjpeg-12.1.1.14-0
# Linking cuda-version-12.5-3
# Linking pytorch-mutex-1.0-cuda
# Linking blas-1.0-mkl
# Linking ld_impl_linux-64-2.38-h1181459_1
# Linking libgfortran5-11.2.0-h1234567_1
# Linking zlib-1.2.13-h5eee18b_1
# Linking yaml-0.2.5-h7b6447c_0
# Linking xz-5.4.6-h5eee18b_1
# Linking xxhash-0.8.0-h7f8727e_3
# Linking utf8proc-2.6.1-h5eee18b_1
# Linking ncurses-6.4-h6a678d5_0
# Linking libwebp-base-1.3.2-h5eee18b_0
# Linking libuuid-1.41.5-h5eee18b_0
# Linking libunistring-0.9.10-h27cfd23_0
# Linking libtasn1-4.19.0-h5eee18b_0
# Linking libiconv-1.16-h5eee18b_3
# Linking libev-4.33-h7f8727e_1
# Linking libdeflate-1.17-h5eee18b_1
# Linking libbrotlicommon-1.0.9-h5eee18b_8
# Linking lame-3.100-h7b6447c_0
# Linking jpeg-9e-h5eee18b_1
# Linking c-ares-1.19.1-h5eee18b_0
# Linking bzip2-1.0.8-h5eee18b_6
# Linking aws-c-common-0.8.5-h5eee18b_0
# Linking s2n-1.3.27-hdbd6064_0
# Linking libevent-2.1.12-hdbd6064_1
# Linking tbb-2021.8.0-hdb19cb5_0
# Linking snappy-1.1.10-h6a678d5_1
# Linking re2-2022.04.01-h295c915_0
# Linking openh264-2.1.1-h4ff587b_0
# Linking lz4-c-1.9.4-h6a678d5_1
# Linking libffi-3.4.4-h6a678d5_1
# Linking lerc-3.0-h295c915_0
# Linking icu-73.1-h6a678d5_0
# Linking gmp-6.2.1-h295c915_3
# Linking gflags-2.2.2-h6a678d5_1
# Linking abseil-cpp-20211102.0-hd4dd3e8_0
# Linking zeromq-4.3.5-h6a678d5_0
# Linking libgfortran-ng-11.2.0-h00389a5_1
# Linking tk-8.6.14-h39e8969_0
# Linking llvm-openmp-14.0.6-h9e868ea_0
# Linking libssh2-1.11.0-h251f7ec_0
# Linking libprotobuf-3.20.3-he621ea3_0
# Linking libpng-1.6.39-h5eee18b_0
# Linking readline-8.2-h5eee18b_0
# Linking libedit-3.1.20230828-h5eee18b_0
# Linking libidn2-2.3.4-h5eee18b_0
# Linking libbrotlienc-1.0.9-h5eee18b_8
# Linking libbrotlidec-1.0.9-h5eee18b_8
# Linking libnghttp2-1.57.0-h2d74bed_0
# Linking aws-checksums-0.1.13-h5eee18b_0
# Linking aws-c-sdkutils-0.1.6-h5eee18b_0
# Linking aws-c-compression-0.2.16-h5eee18b_0
# Linking aws-c-cal-0.5.20-hdbd6064_0
# Linking zstd-1.5.5-hc292b87_2
# Linking intel-openmp-2023.1.0-hdb19cb5_46306
# warning  libmamba [intel-openmp-2023.1.0-hdb19cb5_46306] The following files were already present in the environment:
#     - lib/libiomp5.so
#     - lib/libomptarget.so
# Linking nettle-3.7.3-hbbd107a_1
# Linking mpfr-4.0.2-hb69a4c5_1
# Linking glog-0.5.0-h6a678d5_1
# Linking grpc-cpp-1.48.2-he1ff14a_1
# Linking freetype-2.12.1-h4a9f257_0
# Linking sqlite-3.45.3-h5eee18b_0
# Linking krb5-1.20.1-h143b758_1
# Linking aws-c-io-0.13.10-h5eee18b_0
# Linking orc-1.7.4-hb3bc3d3_1
# Linking libtiff-4.5.1-h6a678d5_0
# Linking libboost-1.82.0-h109eef0_2
# Linking mkl-2023.1.0-h213fc3f_46344
# Linking gnutls-3.6.15-he1e5248_0
# Linking mpc-1.1.0-h10f8cd9_1
# Linking libcurl-8.7.1-h251f7ec_0
# Linking aws-c-http-0.6.25-h5eee18b_0
# Linking aws-c-event-stream-0.2.15-h6a678d5_0
# Linking openjpeg-2.4.0-h9ca470c_1
# Linking lcms2-2.12-h3be6417_0
# Linking boost-cpp-1.82.0-hdb19cb5_2
# Linking aws-c-mqtt-0.7.13-h5eee18b_0
# Linking aws-c-auth-0.6.19-h5eee18b_0
# Linking libthrift-0.15.0-h1795dd8_2
# Linking aws-c-s3-0.1.51-hdbd6064_0
# Linking aws-crt-cpp-0.18.16-h6a678d5_0
# Linking tzdata-2024a-h04d1e81_0
# Linking libjpeg-turbo-2.0.0-h9bf148f_0
# warning  libmamba [libjpeg-turbo-2.0.0-h9bf148f_0] The following files were already present in the environment:
#     - bin/cjpeg
#     - bin/djpeg
#     - bin/jpegtran
#     - bin/rdjpgcom
#     - bin/wrjpgcom
#     - include/jconfig.h
#     - include/jerror.h
#     - include/jmorecfg.h
#     - include/jpeglib.h
#     - lib/libjpeg.a
#     - lib/libjpeg.so
#     - lib/pkgconfig/libjpeg.pc
#     - share/man/man1/cjpeg.1
#     - share/man/man1/djpeg.1
#     - share/man/man1/jpegtran.1
#     - share/man/man1/rdjpgcom.1
#     - share/man/man1/wrjpgcom.1
# Linking ffmpeg-4.3-hf484d3e_0
# Linking libcurand-10.3.6.39-0
# Linking libcufile-1.10.0.4-0
# Linking cuda-opencl-12.5.39-0
# Linking cuda-libraries-12.1.0-0
# Linking cuda-runtime-12.1.0-0
# Linking hdf5-1.12.1-h2b7332f_3
# Linking aws-sdk-cpp-1.10.55-h721c034_0
# Linking python-3.10.12-h955ad1f_0
# Linking wheel-0.43.0-py310h06a4308_0
# Linking arrow-cpp-14.0.2-h374c478_1
# Linking setuptools-69.5.1-py310h06a4308_0
# Linking pytorch-cuda-12.1-ha16c6d3_5
# Linking pip-25.1-pyhc872135_2
# Linking sortedcontainers-2.4.0-pyhd3eb1b0_0
# Linking python-tzdata-2023.3-pyhd3eb1b0_0
# Linking charset-normalizer-2.0.4-pyhd3eb1b0_0
# Linking fsspec-2024.3.1-py310h06a4308_0
# Linking websocket-client-1.8.0-py310h06a4308_0
# Linking typing_extensions-4.11.0-py310h06a4308_0
# Linking tqdm-4.66.4-py310h2f386ee_0
# Linking soupsieve-2.5-py310h06a4308_0
# Linking safetensors-0.4.2-py310ha89cbab_1
# Linking regex-2023.10.3-py310h5eee18b_0
# Linking pyzmq-25.1.2-py310h6a678d5_0
# Linking pyyaml-6.0.1-py310h5eee18b_0
# Linking pytz-2024.1-py310h06a4308_0
# Linking python-xxhash-2.0.2-py310h5eee18b_1
# Linking pysocks-1.7.1-py310h06a4308_0
# Linking pillow-10.3.0-py310h5eee18b_0
# Linking networkx-3.2.1-py310h06a4308_0
# Linking mypy_extensions-1.0.0-py310h06a4308_0
# Linking mpmath-1.3.0-py310h06a4308_0
# Linking mkl-service-2.4.0-py310h5eee18b_1
# Linking markupsafe-2.1.3-py310h5eee18b_0
# Linking joblib-1.4.2-py310h06a4308_0
# Linking idna-3.7-py310h06a4308_0
# Linking h11-0.14.0-py310h06a4308_0
# Linking gmpy2-2.1.2-py310heeb90bb_0
# Linking filelock-3.13.1-py310h06a4308_0
# Linking dill-0.3.8-py310h06a4308_0
# Linking debugpy-1.6.7-py310h6a678d5_0
# Linking click-8.1.7-py310h06a4308_0
# Linking certifi-2024.7.4-py310h06a4308_0
# Linking brotli-python-1.0.9-py310h6a678d5_8
# Linking typing-extensions-4.11.0-py310h06a4308_0
# Linking beautifulsoup4-4.12.2-py310h06a4308_0
# Linking typing_inspect-0.9.0-py310h06a4308_0
# Linking numpy-base-1.26.4-py310hb5e798b_0
# Linking jinja2-3.1.4-py310h06a4308_0
# Linking sympy-1.12-py310h06a4308_0
# Linking multiprocess-0.70.15-py310h06a4308_0
# Linking urllib3-2.2.2-py310h06a4308_0
# Linking numpy-1.26.4-py310h5f9d8c6_0
# Linking mkl_fft-1.3.8-py310h5eee18b_0
# Linking requests-2.32.3-py310h06a4308_1
# Linking mkl_random-1.2.4-py310hdb19cb5_0
# Linking pyarrow-14.0.2-py310h1eedbd7_0
# Linking numexpr-2.8.7-py310h85018f9_0
# Linking h5py-3.9.0-py310he06866b_0
# Linking bottleneck-1.3.7-py310ha9d4c09_0
# Linking zipp-3.19.2-pyhd8ed1ab_0
# Linking widgetsnbextension-4.0.11-pyhd8ed1ab_0
# Linking wcwidth-0.2.13-pyhd8ed1ab_0
# Linking traitlets-5.14.3-pyhd8ed1ab_0
# Linking tenacity-8.4.2-pyhd8ed1ab_0
# Linking sniffio-1.3.1-pyhd8ed1ab_0
# Linking six-1.16.0-pyh6c4a22f_0
# Linking pygments-2.18.0-pyhd8ed1ab_0
# Linking pure_eval-0.2.2-pyhd8ed1ab_0
# Linking ptyprocess-0.7.0-pyhd3deb0d_0
# Linking platformdirs-4.2.2-pyhd8ed1ab_0
# Linking pickleshare-0.7.5-py_1003
# Linking parso-0.8.4-pyhd8ed1ab_0
# Linking packaging-23.2-pyhd8ed1ab_0
# Linking nest-asyncio-1.6.0-pyhd8ed1ab_0
# Linking jupyterlab_widgets-3.0.11-pyhd8ed1ab_0
# Linking executing-2.0.1-pyhd8ed1ab_0
# Linking exceptiongroup-1.2.0-pyhd8ed1ab_2
# Linking decorator-5.1.1-pyhd8ed1ab_0
# Linking attrs-23.2.0-pyh71513ae_0
# Linking pyee-11.0.1-pyhd8ed1ab_0
# Linking wsproto-1.2.0-pyhd8ed1ab_0
# Linking nltk-3.8.1-pyhd8ed1ab_0
# Linking async-timeout-4.0.3-pyhd8ed1ab_0
# Linking annotated-types-0.7.0-pyhd8ed1ab_0
# Linking importlib-metadata-8.0.0-pyha770c72_0
# Linking prompt-toolkit-3.0.47-pyha770c72_0
# Linking matplotlib-inline-0.1.7-pyhd8ed1ab_0
# Linking comm-0.2.2-pyhd8ed1ab_0
# Linking python-dateutil-2.9.0-pyhd8ed1ab_0
# Linking asttokens-2.4.1-pyhd8ed1ab_0
# Linking pexpect-4.9.0-pyhd8ed1ab_0
# Linking jedi-0.19.1-pyhd8ed1ab_0
# Linking huggingface_hub-0.23.4-pyhd8ed1ab_0
# Linking anyio-4.4.0-pyhd8ed1ab_0
# Linking importlib_metadata-8.0.0-hd8ed1ab_0
# Linking stack_data-0.6.2-pyhd8ed1ab_0
# Linking ipython-8.26.0-pyh707e725_0
# Linking ipywidgets-8.1.3-pyhd8ed1ab_0
# Linking python_abi-3.10-2_cp310
# Linking tornado-6.4.1-py310hc51659f_0
# Linking tokenizers-0.19.1-py310h320607d_0
# Linking pydantic-core-2.20.0-py310he421c4c_0
# Linking psutil-6.0.0-py310hc51659f_0
# Linking orjson-3.10.6-py310h42e942d_0
# Linking multidict-6.0.5-py310h2372a71_0
# Linking jupyter_core-5.7.2-py310hff52083_0
# Linking jsonpointer-3.0.0-py310hff52083_0
# Linking greenlet-3.0.3-py310hc6cd4ac_0
# Linking frozenlist-1.4.1-py310h2372a71_0
# Linking yarl-1.9.4-py310h2372a71_0
# Linking sqlalchemy-2.0.31-py310hc51659f_0
# Linking pytorch-2.3.1-py3.10_cuda12.1_cudnn8.9.2_0
# Linking torchtriton-2.3.1-py310
# Linking torchvision-0.18.1-py310_cu121
# Linking torchaudio-2.3.1-py310_cu121
# Linking marshmallow-3.19.0-py310h06a4308_0
# Linking pandas-2.2.2-py310h6a678d5_0
# Linking dataclasses-json-0.6.5-py310h06a4308_0
# Linking outcome-1.1.0-pyhd3eb1b0_0
# Linking pydantic-2.8.0-pyhd8ed1ab_0
# Linking jupyter_client-8.6.2-pyhd8ed1ab_0
# Linking jsonpatch-1.33-pyhd8ed1ab_0
# Linking aiosignal-1.3.1-pyhd8ed1ab_0
# Linking langsmith-0.1.83-pyhd8ed1ab_0
# Linking ipykernel-6.29.5-pyh3099207_0
# Linking langchain-core-0.1.52-pyhd8ed1ab_0
# Linking langchain-text-splitters-0.0.2-pyhd8ed1ab_0
# Linking playwright-1.42.0-py310_0
# Linking trio-0.24.0-py310h06a4308_0
# Linking aiohttp-3.9.5-py310h2372a71_0
# Linking trio-websocket-0.11.1-pyhd8ed1ab_0
# Linking langchain-community-0.0.38-pyhd8ed1ab_0
# Linking selenium-4.22.0-pyhd8ed1ab_1
# Linking langchain-0.1.20-pyhd8ed1ab_0
# Linking datasets-2.19.1-py310h06a4308_0
# Linking transformers-4.42.4-pyhd8ed1ab_0
#
# Transaction finished
#
#
# To activate this environment, use:
#
#     mamba activate ml
#
# Or to execute a single command in this environment, use:
#
#     mamba run -n ml mycommand
#
# warning  libmamba You are using 'pip' as an additional package manager.
#     Be aware that packages installed with 'pip' are managed independently from 'conda-forge' channel.
#
# Installing pip packages: asgiref==3.8.1, backoff==2.2.1, bcrypt==4.1.3, build==1.2.1, cachetools==5.3.3, chroma-hnswlib==0.7.3, chromadb==0.5.3, coloredlogs==15.0.1, dataclasses-json==0.6.7, deprecated==1.2.14, dnspython==2.6.1, email-validator==2.2.0, fastapi==0.111.0, fastapi-cli==0.0.4, flatbuffers==24.3.25, fsspec==2024.6.1, google-auth==2.31.0, googleapis-common-protos==1.63.2, grpcio==1.64.1, httpcore==1.0.5, httptools==0.6.1, httpx==0.27.0, humanfriendly==10.0, importlib-metadata==7.1.0, importlib-resources==6.4.0, kubernetes==30.1.0, langchain-chroma==0.1.2, langchain-community==0.2.6, markdown-it-py==3.0.0, marshmallow==3.21.3, mdurl==0.1.2, mmh3==4.1.0, monotonic==1.6, oauthlib==3.2.2, ollama==0.2.1, onnxruntime==1.18.1, opentelemetry-api==1.25.0, opentelemetry-exporter-otlp-proto-common==1.25.0, opentelemetry-exporter-otlp-proto-grpc==1.25.0, opentelemetry-instrumentation==0.46b0, opentelemetry-instrumentation-asgi==0.46b0, opentelemetry-instrumentation-fastapi==0.46b0, opentelemetry-proto==1.25.0, opentelemetry-sdk==1.25.0, opentelemetry-semantic-conventions==0.46b0, opentelemetry-util-http==0.46b0, overrides==7.7.0, pip==24.1.2, posthog==3.5.0, protobuf==4.25.3, pyasn1==0.6.0, pyasn1-modules==0.4.0, pypdf==4.2.0, pypika==0.48.9, pyproject-hooks==1.1.0, python-dotenv==1.0.1, python-multipart==0.0.9, requests==2.32.3, requests-oauthlib==2.0.0, rich==13.7.1, rsa==4.9, shellingham==1.5.4, starlette==0.37.2, tomli==2.0.1, typer==0.12.3, ujson==5.10.0, uvicorn==0.30.1, uvloop==0.19.0, watchfiles==0.22.0, websockets==12.0, wrapt==1.16.0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 63.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 143.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 71.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 132.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 69.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 101.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.7 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75/75 [langchain-chroma]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.19.1 requires fsspec[http]<=2024.3.1,>=2023.1.0, but you have fsspec 2024.6.1 which is incompatible.

# %% [markdown]
# # Start the LLM server (Ollama)

# %%
import os
import threading
import subprocess
import requests
import json

def ollama():
    os.environ['OLLAMA_HOST'] = '0.0.0.0:11434'
    os.environ['OLLAMA_ORIGINS'] = '*'
    subprocess.Popen(["ollama", "serve"])


ollama_thread = threading.Thread(target=ollama)
ollama_thread.start()

# %% [markdown]
# # Download Embedded and LLM model
#
# There are 2 types of models needed for RAG: An **embedding model** and an **LLM**. The embedding model converts external data like PDF files into vectors and populates the vector database. A user’s query is vectorized and matched to relevant data in the database via similarity search. The LLM receives the query and retrieved context, producing a response that combines its internal knowledge with the new information.
#
# We recommend one of these two embedded models: *nomic-embed-text* or *mxbai-embed-large*. Both models perform well, and we recommend testing them with your dataset to determine which delivers better results. Note that once you select an embedded model, you must use the same model for both indexing (storing data) and querying (retrieving data). There are more embedded models available but they are not recommended since they take more resources.
#
# Your choice of LLM model depends on your GPU's capabilities and your tolerance for wait times.
#
# ## Key Considerations
#
# Larger models (e.g., **Llama4** or **Llama3.3:70B**) require significant GPU RAM (over 50 GB). On platforms like Google Colab, this is only feasible with an A100 GPU. Don't use T4 GPUs for these models, as they are incompatible.
#
# Speed vs. Quality: Larger models deliver higher-quality outputs but respond slower. Smaller models are faster but produce less accurate results.
#
# Balance: For a middle ground between speed, resource usage, and output quality, consider **Gemma:12B** or **Llama3.1:8B**.
#
# T4 Compatibility: **Phi4** offers strong performance and, despite its size, is compatible with T4 GPUs.
#
# Don't use V2 TPU on Google Colab since it is slow for most tasks from the notebook.

# %%
# @title Select models to download
import subprocess
# @markdown ---
# @markdown Select an embedding model:

embedding_model = "mxbai-embed-large" # @param ["nomic-embed-text", "mxbai-embed-large", "bge-m3"]
# !ollama pull {embedding_model}

# @markdown Select a LLM model:

LLM_model = "gemma3:4b" # @param ["phi4", "deepseek-r1:7b", "gemma3:4b", "gemma3:12b", "llama4", "llama3.3:70b", "llama3.2:3b", "llama3.1:8b"]
# !ollama pull {LLM_model}
# @markdown ---
# @markdown ### For more information on available models, check [Ollama](https://ollama.com/search)

# !ollama list
# Out:
# NAME                        ID              SIZE      MODIFIED
# gemma3:4b                   a2af6cc3eb7f    3.3 GB    Less than a second ago
# mxbai-embed-large:latest    468836162de7    669 MB    36 seconds ago

# %% [markdown]
# Next cell reads all the PDF files in the **data_dir** directory, and it is processed into a Vector database named **db_name** and located at **db_dir**

# %% [markdown]
# # Data ingestion
#
# xzzcxczcxzcxzcxz

# %%
# @title Convert your data and load the vector DB
# @markdown X

# @markdown ---
# @markdown ### Directory with source data (PDFs):
data_dir = "/content/ai/data/blastpdfs/" # @param {type:"string"}
# @markdown ### Vector database name and path:
db_name = "blastdb" # @param {type:"string"}
db_dir = "/content/testdata1/" # @param {type:"string"}
# @markdown ---
# !/content/miniforge3/envs/ml/bin/python ai/scripts/createDBColab.py --db_dir {db_dir} --db_name {db_name} --v_llm {embedding_model} --input_dir {data_dir}
# Out:
# Vector model: mxbai-embed-large
# Current documents:
# 0
# Current documents:
# 535
# **

# %% [markdown]
# Note:
#
# CPU: 40m

# %% [markdown]
# Note:
#
# CPU: 46m

# %% [markdown]
# The standard dynamic programming algorithms for pairwise
#  sequence alignment perform a fixed amount of computation per
#  cell of a path graph, whose dimensions are the lengths of the two
#  sequences being compared
#
#
# Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise
#  sequence alignment
#
#
#  =======
#
#   The alignment of a simple sequence with a pattern embodied by
#  a position-specific score matrix is almost completely analogous
#  to the alignment of two simple sequences. The only real
#  difference is that the score for aligning a letter with a pattern
#  position is given by the matrix itself, rather than with reference to
#  a substitution matrix.
#
#  What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
#
#  ===========
#
#
#   Two criteria were most important in the design of the new
#  BLAST code.  1.) the code structure should be modular
#  enough to allow easy modification; and 2.) the same
#  BLAST code should be embedded in at least two different
#  host toolkits.
#
#
#  Which are the 2 most important criteria to design the new BLAST code?

# %%
from google.colab import widgets


# @title Compare RAG query vs LLM query

# @markdown ---
# @markdown Select the embedded model:
embedded_model = "mxbai-embed-large" # @param ["nomic-embed-text", "mxbai-embed-large"]
# @markdown Select the LLM model:
LLM_model = "gemma3:4b" # @param ["phi4", "deepseek-r1:7b", "gemma3:4b", "gemma3:12b", "llama4", "llama3.3:70b", "llama3.2:3b", "llama3.1:8b"]
# @markdown Enter vector database directory and name:
db_dir = "/content/testdata1/" # @param {type:"string"}
db_name = "blastdb" # @param {type:"string"}
# @markdown Enter a prompt:
query = "What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences?" # @param {type:"string"}
# @markdown ---

pypath = "/content/miniforge3/envs/ml/bin/python"
grid = widgets.Grid(1, 2, header_row=True, header_column=True)


with grid.output_to(0, 0):
    print(f"Query against the LLM ({LLM_model})")
    # !ollama run {LLM_model} {query}
with grid.output_to(0, 1):
    print(f"Query against the RAG ({LLM_model} and {db_name} vector database)")
    # !{pypath} ai/scripts/RAG_query.py --e_model {embedded_model} --LLM_model {LLM_model} --db_dir {db_dir} --db_name {db_name} --query "{query}"
# Out:
# <style>
#        table#id2, #id2 > tbody > tr > th, #id2 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id2><tr><th id=id2-0-0></th><th id=id2-0-1></th></tr></table>
# Query against the LLM (gemma3:4b)
# You've hit on a really important distinction in bioinformatics – the difference between aligning a sequence to a *pattern* and aligning two sequences. Let's break it down:
#
# **1. Alignment to a Position-Specific Score Matrix (PSSM) – Aligning to a Pattern**
#
# * **What it is:**  A PSSM (also called a Profile HMM or Position Specific Scoring Matrix) represents a statistical profile of a known sequence motif. It's essentially a matrix where each column corresponds to a position in the motif, and each row represents the probability of finding a specific amino acid (or nucleotide) at that position.
#
# * **The Goal:** You're trying to find *occurrences* of that known motif within a larger sequence.
#
# * **How it Works:** The alignment algorithm (like Smith-Waterman or Needleman-Wunsch) doesn’t just compare one sequence to another. Instead, it slides the motif (represented by the PSSM) across the query sequence. At each position, the algorithm calculates a score based on how well the amino acids/nucleotides in the PSSM match the sequence. Higher scores indicate a better match.
#
# * **Example:** Imagine you have a PSSM for a conserved binding site for a transcription factor. You're looking for that binding site in a gene sequence. The alignment isn't about finding a perfect, linear match. It's about finding *regions* where the sequence closely resembles the motif (i.e., has high scores in the PSSM columns at those positions).  There might be mismatches, but overall the alignment reflects the presence of the motif.
#
# **2. Alignment of Two Simple Sequences**
#
# * **What it is:** This is the standard sequence alignment. You're comparing two sequences directly, trying to find the best linear arrangement of matches, mismatches, and gaps to maximize a score.
#
# * **The Goal:** To determine the evolutionary relationship between the sequences, infer function, or simply represent their similarity.
#
# * **How it Works:** The algorithm considers every possible alignment (including insertions, deletions, and substitutions) between the two sequences and assigns a score based on the match/mismatch scores. The optimal alignment is the one with the highest score.
#
# * **Example:**  If you're comparing the DNA sequences of human and chimpanzee, you’re looking for the sequence differences that arose over evolution.
#
#
# **Here’s a table to summarize the key differences:**
#
# | Feature             | Alignment to PSSM (Pattern) | Alignment of Two Sequences |
# |----------------------|-----------------------------|---------------------------|
# | **Input**           | Query sequence + PSSM      | Two sequences            |
# | **Goal**             | Find occurrences of a motif  | Maximize sequence similarity |
# | **Approach**         | Slide the pattern across the query | Consider all linear arrangements |
# | **Output**           | Locations of motif occurrences | Optimal linear alignment     |
# | **Sequence Lengths** | Often one long, one short      | Generally similar lengths  |
#
#
#
# **In essence:**
#
# * A PSSM alignment is about *motif detection*.
# * A standard sequence alignment is about finding *similarity* between two sequences.
#
# ---
#
# Do you want to delve deeper into any specific aspect of this, such as:
#
# *   The scoring matrices used in PSSM alignment?
# *   How PSSMs are created?
# *   The algorithms used for each type of alignment?
# Query against the RAG (gemma3:4b and blastdb vector database)
# Embedding model: mxbai-embed-large
# LLM: gemma3:4b
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences?
#
# The alignment of a simple sequence with a pattern embodied by a position-specific score matrix is almost completely analogous to the alignment of two simple sequences. The only real difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix. For proteins, a query of length L and a substitution matrix of dimension 20 ×20 are replaced by a position-specific matrix of dimension L ×20. Position-specific gap costs may be defined as well. As with pairwise sequence comparison, one may choose among finding the best global alignment of the matrix and the simple sequence, finding the best alignment of the complete matrix with a segment of the sequence, and finding the best local alignment of the matrix and sequence.
# ***********

# %%
# @title Run a query against the LLM
# @markdown This query will be done without using RAG

# @markdown ---
# @markdown ### Select a model:
LLM_model = "phi4" # @param ["phi4", "gemma3:4b", "gemma3:12b", "llama4", "llama3.3:70b", "llama3.2:3b", "llama3.1:8b"]
# @markdown ### Enter a prompt:
query = "What is the MedGen data model? Provide a list of data elements aggregated in MedGen" # @param {type:"string"}
# @markdown ---

# !ollama run {LLM_model} {query}
# Out:
# ⠙ ⠙ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠏ ⠋ ⠹ ⠸ ⠸ ⠴ ⠴ ⠧ ⠇ ⠇ ⠏ ⠙ ⠹ ⠹ ⠸ ⠼ ⠦ ⠦ ⠧ ⠇ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠹ ⠸ ⠼ ⠴ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠼ ⠴ ⠴ ⠦ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ ⠦ ⠦ ⠇ ⠇ ⠋ ⠙ ⠹ ⠸ ⠸ ⠴ ⠴ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠹ ⠹ ⠼ ⠼ ⠦ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠸ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠏ ⠙ ⠙ ⠹ ⠼ ⠴ ⠴ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠸ ⠼ ⠴ ⠦ ⠦ ⠇ ⠇ ⠋ ⠋ ⠹ ⠹ ⠸ ⠴ ⠦ ⠧ ⠧ ⠇ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠹ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠹ ⠼ ⠴ ⠴ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ MedGen, developed by the U.S. National Library of Medicine (NLM), is part of the Unified Medical Language System (UMLS) and serves as a knowledge base for medical concepts related to diseases, disorders, gene/protein phenotypes, clinical drugs, and other biomedically relevant entities. The data model of MedGen primarily focuses on organizing and interrelating these entities based on their semantic relationships, such as "is a," "associated with," or "treated by."
#
# ### Key Features of the MedGen Data Model:
#
# 1. **Concepts**: These are central elements in MedGen representing medical terms and synonyms from various sources.
# 2. **Relationships**: Connections between concepts that define how they relate to one another (e.g., hierarchical relationships like "is a type of").
# 3. **Source Information**: Each concept includes metadata about its source, such as the database or literature it originated from.
#
# ### Data Elements Aggregated in MedGen:
#
# 1. **Concept IDs**: Unique identifiers for each medical term.
# 2. **Names and Synonyms**: Different terms used to describe the same concept, including preferred names.
# 3. **Semantic Types**: Categories that classify concepts into broader groups (e.g., disease or disorder).
# 4. **Relationships**: Links between concepts with specific relationship types (e.g., "is a," "treated by").
# 5. **Source Databases**: Information about where the term was sourced from, such as MeSH, SNOMED CT, ICD-10.
# 6. **Preferred Names and Unique Identifiers**: Preferred terminology for each concept to standardize references across different systems.
#
# MedGen acts as a bridge among various biomedical terminologies and databases by providing a unified framework that integrates diverse medical vocabularies into a cohesive knowledge base. This integration aids in improving interoperability and facilitating more effective information retrieval and analysis within the biomedical research community.

# %%
# @title Run a RAG query
# @markdown This is a RAG query (based in your data)

# @markdown ---
# @markdown ### Select the embedded model:
embedded_model = "mxbai-embed-large" # @param ["nomic-embed-text", "mxbai-embed-large"]
# @markdown ### Select the LLM model:
LLM_model = "phi4" # @param ["phi4", "gemma3:4b", "gemma3:12b", "llama4", "llama3.3:70b", "llama3.2:3b", "llama3.1:8b"]
# @markdown ### Enter vector database directory and name:
db_dir = "/content/testdata1/" # @param {type:"string"}
db_name = "blastdb" # @param {type:"string"}
# @markdown ### Enter a prompt:
query = "What is the MedGen data model? Provide a list of data elements aggregated in MedGen" # @param {type:"string"}
# @markdown ---

pypath = "/content/miniforge3/envs/ml/bin/python"
# !{pypath} ai/scripts/RAG_query.py --e_model {embedded_model} --LLM_model {LLM_model} --db_dir {db_dir} --db_name {db_name} --query "{query}"
# Out:
# Embedding model: mxbai-embed-large
# LLM: phi4
# Q: What is the MedGen data model? Provide a list of data elements aggregated in MedGen
#
# The MedGen data model is designed to organize information about human disorders and phenotypes with a genetic component. Once a concept is identified, categories of related information are reported, including descriptors, links to other databases, or concept-concept relationships.
#
# Key components aggregated in MedGen for each concept include:
#
# - **Author Affiliation:** Information such as NCBI contact details.
# - **Definitions/Descriptions:** Single definitions prioritized from sources like GTR® and SNOMED CT®, with attribution and source links.
# - **Identifiers:** Maintenance of identifiers from source databases, supporting interactive searching and linking to source websites. Alternative IDs from the Human Phenotype Ontology (HPO) are also included.
# - **Gene-phenotype Relationships:** Reports symbols of causative genes, along with links to NCBI’s Gene database and OMIM®.
# - **Cytogenetic Locations:** Reported based on gene locations contributing to a disorder from ClinVar.
# - **Inter-concept Relationships:**
#   - Diagnosis-clinical feature relationships
#   - Hierarchies including clinical features, disorders (computed or curated by GTR®/ClinVar staff)
# - **Published Literature:** Includes curation of professional guidelines, aggregation from contributors like ClinVar and GTR®, and identification of related literature using PubMed.
#
# These components are organized around a stable unique identifier for each concept, allowing MedGen to serve as a centralized access point for diverse content related to human disorders.
# ***********

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model gemma3:4b --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: gemma3:4b
# Q: Which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria to design the new BLAST code are:
#
# 1.  **Task:** The task setting changes the default values of command-line arguments, including nucleotide match and mismatch values, to optimize the search for different scenarios. Specifically, for the MEGABLAST task, the values are 1 and -2, corresponding to 95% identity matches, while for BLASTN and DISCONTIGUOUS MEGABLAST, the values are 2 and -3 corresponding to 85% identity.
# 2.  **Sequence filtering applications (segmasker, dustmasker, windowmasker):** Integration with these applications via configuration parameters or command-line options to filter sequences based on complexity or other criteria.
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# Here’s a breakdown of the MedGen data model and the components of a MedGen record, based on the provided text:
#
# **MedGen Data Model**
#
# MedGen employs a simple data model. Once a concept (a disorder or phenotype) is identified, related information is categorized and reported. These categories include:
#
# *   **Descriptors:** General terms describing the concept.
# *   **Links to other databases:** Connections to other NCBI and non-NCBI databases.
# *   **Concept-concept relationships:** Links between different concepts, including:
#     *   **Diagnosis-clinical feature relationships:** Linking disorders to their clinical features.
#     *   **Hierarchies:** Organized groupings of concepts (clinical features, disorders, and disorders curated by GTR®/ClinVar staff).
#
# **Components of a MedGen Record**
#
# A MedGen record contains the following key components:
#
# *   **Author Affiliation:** Identifies the source of the record.
# *   **Definition/Description:**  A textual explanation of the concept.
# *   **Clinical Findings:**  Reported clinical manifestations.
# *   **Causative Genetic Variants:** Genes associated with the disorder.
# *   **Gene Information:** Links to NCBI’s Gene database and OMIM®.
# *   **Cytogenetic Locations:** Locations reported from ClinVar based on genes.
# *   **Concept ID:** A unique identifier for the concept.
# *   **Semantic Type:** Categorizes the concept.
# *   **Metadata:**  A collection of attributes, which may vary based on the concept.
#
# Additionally, MedGen records provide access to:
#
# *   **Reviews and Related Information:**  GeneReviews, PubMed Clinical Queries, and Reviews in PubMed.
# *   **Molecular Resources:** Information related to molecular aspects of the disorder.
# *   **Consumer Resources:**  Information geared towards patients and their families.
# *   **Clinical Trials:** Links to clinical trials related to the disorder.
# *   **Professional Guidelines:** Links to relevant guidelines.
# *   **Original and Review Literature:**  Links to scientific publications.
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment are determined by the length of the query sequence and the substitution matrix used. Specifically, the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix. For proteins, a query of length L and a substitution matrix of dimension 20 × 20 are replaced by a position-specific matrix of dimension L × 20.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The only real difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix. For proteins, a query of length L and a substitution matrix of dimension 20 ×20 are replaced by a position-specific matrix of dimension L ×20. Position-specific gap costs may be defined as well (34,40). As with pairwise sequence comparison, one may choose among finding the best global alignment of the matrix and the simple sequence (23), finding the best alignment of the complete matrix with a segment of the sequence (41), and finding the best local alignment of the matrix and sequence (24).
# ***********

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model gemma3:4b --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: gemma3:4b
# Q: Regarding Blast+, which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria to design the new BLAST code are:
#
# 1.  **Reward megablast integer 1**
# 2.  **Penalty megablast integer -2**
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# Here’s a breakdown of the MedGen data model and the components of a MedGen record, based on the provided text:
#
# **MedGen Data Model:**
#
# The MedGen data model is designed to be simple. It centers around identifying a concept (a disorder or phenotype) and then gathering and reporting information related to that concept. This information is categorized as:
#
# *   **Descriptors:** General descriptions of the concept.
# *   **Links to other databases:** Connections to resources like NCBI databases, OMIM®, and ClinVar.
# *   **Concept-Concept Relationships:** Links between related disorders, features, or other concepts.
#
# **Components of a MedGen Record:**
#
# A MedGen record contains several key components, including:
#
# *   **Author Affiliation:** Information about the contributors.
# *   **Concept Name:** The identifier for the specific disorder or phenotype.
# *   **Definition/Description:** A textual definition of the concept.
# *   **Clinical Findings:** Reported clinical features associated with the concept.
# *   **Causative Genetic Variants:** Genes and genetic variations associated with the disorder.
# *   **Molecular Resources:** Information regarding the molecular aspects of the concept.
# *   **Professional Guidelines:** Access to relevant professional guidelines.
# *   **Literature:** Links to original and review literature.
# *   **Consumer Resources:** Information for patient and public understanding.
# *   **Clinical Trials:** Links to clinical trials related to the concept.
# *   **Web Links:** Links to other NCBI and non-NCBI resources.
# *   **Concept ID:** A unique identifier for the concept.
# *   **Semantic Type:** Categorizes the type of information (e.g., gene, disorder, feature).
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment are determined by the length of the query sequence (L) and the size of the substitution matrix (20x20 for proteins). Specifically, the computation is tied to the number of comparisons made during the extension of the alignment, which is directly related to the length of the query and the size of the substitution matrix used to score those comparisons.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The only real difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix. For proteins, a query of length L and a substitution matrix of dimension 20 ×20 are replaced by a position-specific matrix of dimension L ×20. Position-specific gap costs may be defined as well (34,40). As with pairwise sequence comparison, one may choose among finding the best global alignment of the matrix and the simple sequence (23), finding the best alignment of the complete matrix with a segment of the sequence (41), and finding the best local alignment of the matrix and sequence (24).
# ***********

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model llama3.1:8b --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: llama3.1:8b
# Q: Regarding Blast+, which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria to design the new BLAST code are:
#
# 1. **Scoring parameters**: The scoring parameters for insertions, deletions, and mismatches need to be defined, which include:
# 	* Reward (or match score) for a nucleotide match
# 	* Penalty for a nucleotide mismatch
# 2. **Gap penalty strategy**: The gap penalty strategy needs to be defined, which can be either a linear gap penalty or an affine gapping strategy.
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is a simple data model that once a concept is identified, categories of information related to that concept are identified and reported.
#
# A MedGen record has several important components including:
#
# * Author Affiliation
# * Concept ID (a stable unique identifier)
# * Definition or description
# * Clinical findings
# * Causative genetic variants and the genes in which they occur
# * Available clinical and research tests
# * Molecular resources
# * Professional guidelines
# * Original and review literature
# * Consumer resources
# * Clinical trials
# * Web links to other related NCBI and non-NCBI resources
#
# These components are organized into categories of information that relate to the concept, including descriptors, links to other databases, or concept-concept relationships.
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# I don't know.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix and the alignment of two simple sequences is that the score for aligning a letter with a pattern position in the first case is given by the matrix itself, rather than with reference to a substitution matrix.
# ***********

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model gemma3:12b --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: gemma3:12b
# Q: Regarding Blast+, which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria to design the new BLAST code are near gap penalty and affine gapping.
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is simple: once a concept is identified, categories of information related to that concept are identified and reported.
#
# A MedGen record has several important components including:
# *   Author Affiliation
# *   Definition or description
# *   Clinical findings
# *   Causative genetic variants and genes
# *   Clinical and research tests
# *   Molecular resources
# *   Professional guidelines
# *   Literature
# *   Consumer resources
# *   Clinical trials
# *   Web links
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The context does not explicitly state the dimensions of the fixed amount of computation per cell of a path graph in standard dynamic programming algorithms for pairwise sequence alignment.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The alignment of a simple sequence with a pattern embodied by a position-specific score matrix is almost completely analogous to the alignment of two simple sequences. The only real difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix.
# ***********

# %%
# !ollama run llama3.2:3b "Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment"
# Out:
# ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠸ ⠼ ⠼ ⠴ ⠦ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠙ ⠹ ⠼ ⠴ ⠴ ⠦ In the standard dynamic programming (DP) algorithms for pairwise sequence alignment, such as Needleman-Wunsch or Smith-Waterman, each cell in the scoring matrix represents a certain amount of computation.
#
# The dimensions of this fixed amount of computation per cell are:
#
# * **Rows**: The number of rows corresponds to the length of one of the sequences being aligned. Specifically, it's the length of the sequence with more positions, or 0 if both sequences have the same length.
# * **Columns**: The number of columns also corresponds to the length of the other sequence being aligned.
#
# In other words, each cell in the scoring matrix represents a trade-off between:
#
# 1. Matching a character at position i in one sequence and its corresponding character at position j in the other sequence (scored as +1).
# 2. Not matching these characters (scored as -1 for penalties, if present).
#
# For example, if we have two sequences of lengths 10 and 12, respectively, the scoring matrix will be a 10x12 matrix.
#
# The computation cost per cell is typically assumed to be constant across the entire scoring matrix, which is why the problem statement mentions that it's fixed.

# %%
# !ollama run llama4 "Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment"
# Out:
# ⠙ ⠹ ⠸ ⠼ ⠴ Error: model requires more system memory (56.0 GiB) than is available (11.4 GiB)

# %%
# !ollama run gemma3:12b "Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment"
# Out:
# ⠋ ⠹ ⠸ ⠼ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ ⠼ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ ⠦ ⠧ ⠇ ⠇ ⠏ ⠋ ⠹ ⠹ ⠼ ⠼ ⠦ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ ⠴ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠸ ⠸ ⠴ ⠴ ⠦ ⠧ ⠏ ⠋ ⠙ ⠙ ⠸ ⠸ ⠼ ⠦ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠧ ⠏ ⠏ ⠋ ⠙ ⠸ ⠼ ⠴ ⠴ ⠧ ⠇ ⠇ ⠋ ⠙ ⠙ ⠸ ⠼ ⠼ ⠴ ⠦ ⠇ ⠏ ⠏ ⠙ ⠙ ⠸ ⠸ ⠴ ⠴ ⠧ ⠧ ⠏ ⠋ ⠙ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠼ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠏ ⠙ ⠹ ⠸ ⠸ ⠼ ⠴ ⠧ ⠧ ⠏ ⠏ ⠙ ⠹ ⠹ ⠸ ⠼ ⠦ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠸ ⠸ ⠼ ⠦ ⠦ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠼ ⠼ ⠦ ⠧ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ ⠼ ⠴ ⠴ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠙ ⠸ ⠼ ⠴ ⠦ ⠦ ⠧ ⠇ ⠋ ⠙ ⠹ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠏ ⠋ ⠙ ⠸ ⠼ ⠼ ⠴ ⠦ ⠧ ⠏ ⠏ ⠙ ⠹ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠙ ⠙ ⠹ ⠸ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠸ ⠼ ⠴ ⠴ ⠧ ⠇ ⠇ ⠏ Okay, let's break down the dimensions of the fixed computation per cell in dynamic programming algorithms for pairwise sequence alignment (specifically, focusing on standard approaches like Needleman-Wunsch and Smith-Waterman).
#
# **Understanding the Context: Dynamic Programming for Sequence Alignment**
#
# Dynamic programming (DP) for sequence alignment constructs a table (or matrix) where each cell represents the optimal alignment score for a specific prefix of the two sequences being compared.  The final score in the bottom-right cell is the overall alignment score. The table is filled bottom-up, using previously calculated scores.
#
# **The Computation Per Cell - The Core**
#
# The key is understanding *what* calculation happens to fill a cell.  Generally, the score for cell `(i, j)` in the alignment matrix is calculated using the following formula (Needleman-Wunsch - global alignment):
#
# `Score(i, j) = max {
#     Score(i-1, j-1) + match/mismatch_score(sequence1[i], sequence2[j]),  // Match/Mismatch
#     Score(i-1, j) + gap_penalty,      // Gap in sequence 1
#     Score(i, j-1) + gap_penalty       // Gap in sequence 2
# }`
#
# For Smith-Waterman (local alignment), the formula is similar, but with a crucial addition:
#
# `Score(i, j) = max {0,
#     Score(i-1, j-1) + match/mismatch_score(sequence1[i], sequence2[j]),  // Match/Mismatch
#     Score(i-1, j) + gap_penalty,      // Gap in sequence 1
#     Score(i, j-1) + gap_penalty       // Gap in sequence 2
# }`
#
# **Dimensions of Computation per Cell**
#
# Let's analyze the components of the computation and their "dimensions" or the operations involved.
#
# 1.  **Accessing Previous Scores (Lookup):** This is the most significant part of the computation.  A cell's value depends on three or four neighboring cells.
#     *   `Score(i-1, j-1)`:  Accessing the diagonally upper-left cell.
#     *   `Score(i-1, j)`: Accessing the cell directly above.
#     *   `Score(i, j-1)`: Accessing the cell to the left.
#     *   (For Smith-Waterman) 0:  The 0 value is used to initiate local alignment.
#
#     *Dimension:* These are constant-time operations (assuming the table is stored in memory or a cache that allows quick access).  They are primarily memory access operations.
#
# 2.  **Match/Mismatch Score Calculation:**
#     *   `match/mismatch_score(sequence1[i], sequence2[j])`: This function determines the score based on whether the characters at positions `i` and `j` match or mismatch. This might be a simple +1 for a match, -1 for a mismatch, or more complex depending on the scoring system used.
#     *Dimension:* Usually a few simple comparisons and a constant-time operation.  The complexity depends on the scoring system (e.g., a more sophisticated scoring matrix might involve looking up values).
#
# 3.  **Gap Penalty:** This is a constant value (or a function of the position if you have gap penalties that vary). It's typically a negative value.
#     *Dimension:*  This is simply adding a constant value to the calculated scores.  It's a constant-time operation.
#
# 4.  **Maximum Function:**  You need to take the `max` (or `max(0)` for Smith-Waterman) of the three or four values you're comparing.
#     *Dimension:* Constant time. This involves comparing 3 or 4 numbers and selecting the largest one.
#
# **Putting it Together - Summary of Dimensions**
#
# Here's a summary of the dimensions (meaning, what operations are involved) per cell computation:
#
# *   **Memory Access (Lookups):** O(1) – Constant time (accessing three/four cells). This is the dominant operation.
# *   **Match/Mismatch Score:** O(1) - Constant time (typically, but could be more complex with more sophisticated scoring schemes)
# *   **Gap Penalty:** O(1) – Constant time
# *   **Maximum Function:** O(1) – Constant time
#
# **Overall Complexity per Cell**
#
# Despite the individual components having constant-time complexity, the *overall* complexity per cell in the dynamic programming algorithms is still considered *O(1)*.  This is because the constant factors involved in the individual operations remain the same regardless of the input sequence lengths. The overall algorithm's complexity is determined by the number of cells in the table (m x n where m and n are the lengths of the sequences) resulting in O(mn).
#
# **Key Considerations**
#
# *   **Scoring System:**  If your `match/mismatch_score` calculation involves looking up values from a large scoring matrix (e.g., PAM or BLOSUM), that lookup could introduce a logarithmic factor in the complexity per cell (O(log k), where 'k' is the size of the matrix).  This is less common but possible.
# *   **Implementation Details:** The specific implementation can influence the actual runtime.  Cache behavior, memory alignment, and compiler optimizations can play a role.
#
# In conclusion, while each individual operation is quite simple and constant time, the collective effect of these operations defines the "fixed amount of computation" within each cell during dynamic programming sequence alignment. The most significant part is the memory access to retrieve values from previously calculated cells.

# %%
# !ollama run gemma3:12b "What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences"
# Out:
# ⠙ ⠹ Okay, let's break down the difference between aligning a sequence to a Position-Specific Scoring Matrix (PSSM) versus aligning two simple sequences.  The core concept is that PSSMs offer a more nuanced and sophisticated way of capturing the "pattern" you're trying to find compared to a direct sequence-to-sequence comparison.
#
# **1. Aligning Two Simple Sequences (Traditional Sequence Alignment)**
#
# * **What it is:** This is the classic sequence alignment you probably learned about first.  It involves comparing two DNA, RNA, or protein sequences and finding the best possible arrangement (introducing gaps if necessary) to maximize the similarity between them.
# * **Scoring:**  It uses a simple scoring system.  Generally:
#     * **Match:** Positive score (e.g., +1, +2) - When the characters at aligned positions are the same.
#     * **Mismatch:** Negative score (e.g., -1, -2) - When the characters are different.
#     * **Gap Penalty:** Negative score (either gap open penalty for introducing a gap and a gap extension penalty for extending an existing gap).
# * **Goal:**  Maximize the overall alignment score.
# * **Example:** Imagine aligning "ATGC" and "AGTC".  The algorithm will try different alignments, like:
#     *  `ATGC`
#        `AGTC`   (Few mismatches)
#     *  `ATGC`
#        `A-GTC` (One gap)
#     *  `A-TGC`
#        `AGTC` (Multiple gaps)
#     It will select the alignment with the highest score based on its defined scoring system.
# * **Limitations:**
#     * **Uniform Scoring:**  It treats all mismatches equally.  A mismatch between 'A' and 'G' is treated the same as a mismatch between 'A' and 'C', even though in many biological contexts, A-G mismatches might be less disruptive than A-C mismatches.
#     * **Ignores Context:** It doesn't inherently account for the fact that some positions in a sequence are more "important" or "conserved" than others.  For example, a highly conserved motif (a recurring pattern) might be crucial, while other positions could be more variable.
#     * **Sensitive to Length Differences:**  Large length differences can skew the results.
#
# **2. Aligning a Sequence to a Position-Specific Scoring Matrix (PSSM)**
#
# * **What it is:**  A PSSM (also known as a Profile) is a matrix that summarizes the frequencies of amino acids (or nucleotides) at each position in a multiple sequence alignment (MSA). It represents a "pattern" or "consensus" derived from a family of related sequences.
# * **How it's Created:** You start with an MSA of sequences that are believed to be related (e.g., members of a protein family).  The PSSM is then constructed by counting how often each amino acid (or nucleotide) appears at each position within that MSA.  This creates a matrix where each row represents an amino acid, and each column represents a position in the alignment.
# * **Scoring:**  Instead of a single score for a mismatch, each position in the PSSM has its own score table. The score of an alignment at a specific position depends on the actual amino acid (or nucleotide) in the target sequence and the score assigned to that amino acid in the PSSM at that position.
#     * **High-scoring amino acids:** Positions where a few amino acids are frequently observed get high scores.
#     * **Ambiguous positions:** Positions with a more diverse set of amino acids have lower scores (often near zero).
# * **Alignment Algorithm:**  Typically uses dynamic programming algorithms similar to traditional sequence alignment, but the scoring function is now the PSSM.  This means the algorithm doesn't just maximize a global score; it optimizes the alignment based on the "preferences" encoded within the PSSM.
# * **Goal:** Find the region of the target sequence that best matches the "pattern" defined by the PSSM.
# * **Benefits:**
#     * **Accounts for Conservation:** Positions that are highly conserved across the MSA will have high-scoring amino acids in the PSSM, making them more likely to produce a high-scoring alignment.
#     * **Sensitive to Distantly Related Sequences:** Can detect relationships that traditional alignment might miss.  Even if a sequence is only distantly related to the sequences used to create the PSSM, it might still produce a high-scoring alignment if it contains the key features represented by the matrix.
#     * **Handles Variable Positions:** Positions with more variation across the sequences used to generate the PSSM have less discriminatory scoring.  This allows for sequence divergence while still identifying functionally related sequences.
#
# **Here's a Table to Summarize the Key Differences:**
#
# | Feature | Aligning Two Simple Sequences | Aligning to a PSSM |
# |---|---|---|
# | **Pattern Representation** | Simple scoring system (match/mismatch/gap penalties) | Position-specific scores reflecting conservation/variability from an MSA |
# | **Scoring** | Uniform scoring for mismatches | Position-dependent scoring based on the PSSM |
# | **Sensitivity to Conservation** | Limited | High |
# | **Detection of Distant Relationships** | Less sensitive | More sensitive |
# | **Complexity** | Simpler | More complex (requires an MSA to create the PSSM) |
# | **Biological Relevance** | Good for finding close homologs | Good for finding distantly related proteins with similar motifs |
#
# **Analogy:**
#
# * **Two Simple Sequences:** Imagine comparing two people based on a simple questionnaire ("Do you like apples?  Yes/No").  The comparison is straightforward but doesn't account for nuances.
# * **PSSM Alignment:** Imagine comparing someone's personality to a detailed profile of someone from a specific profession (e.g., a scientist).  The profile considers multiple traits and assigns weights to each, reflecting their relative importance.  This allows you to identify people who share key characteristics, even if they don't perfectly match every aspect of the profile.
#
#
#
# I hope this comprehensive explanation clarifies the difference between these two types of sequence alignment.  Do you have any further questions?

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model gemma3:12b --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: gemma3:12b
# Q: Which are the 2 most important criteria to design the new BLAST code?
# Reward for a nucleotide match and penalty for a nucleotide mismatch.
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# A MedGen record has components including a definition or description, clinical findings, causative genetic variants, available clinical and research tests, molecular resources, professional guidelines, literature, consumer resources, clinical trials, and Web links.
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# I do not have the answer.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The alignment of a sequence with a pattern embodied by a position-specific score matrix is almost completely analogous to the alignment of two simple sequences.
# ***********

# %%
# changed rag context question
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model gemma3:12b --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: gemma3:12b
# Q: Which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria to design the new BLAST code are: nucleotide match reward (1 or 2) and nucleotide mismatch penalty (-2 or -3).
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is simple: once a concept is identified, categories of information related to that concept are identified and reported.
#
# A MedGen record has several important components including:
# *   Author Affiliation
# *   Links to other databases
# *   Concept-concept relationships
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The text does not specify the exact dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The alignment of a simple sequence with a pattern embodied by a position-specific score matrix is almost completely analogous to the alignment of two simple sequences. The only real difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix.
# ***********

# %%
# changed rag context question
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model gemma3:12b --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: gemma3:12b
# Q: Which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria to design the new BLAST code are the reward for a nucleotide match and the penalty for a nucleotide mismatch.
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is simple: once a concept is identified, categories of information related to that concept are identified and reported.
#
# A MedGen record has several important components including:
# *   Author Affiliation
# *   Clinical findings
# *   Causative genetic variants and the genes in which they occur
# *   Available clinical and research tests
# *   Molecular resources
# *   Professional guidelines
# *   Original and review literature
# *   Consumer resources
# *   Clinical trials
# *   Web links
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The context doesn't specify the exact dimensions of the fixed amount of computation per cell of a path graph in standard dynamic programming algorithms for pairwise sequence alignment.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The alignment of a simple sequence with a pattern embodied by a position-specific score matrix is almost completely analogous to the alignment of two simple sequences. The only real difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix.
# ***********

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model phi4 --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: phi4
# Q: Which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria for designing the new BLAST code are:
#
# 1. **Reward and Penalty Values**: These determine how nucleotide matches and mismatches affect scoring during searches. For example, different tasks such as "megablast," "blastn," and "dc-megablast" have specific reward and penalty values assigned to optimize search performance for particular scenarios.
#
# 2. **Gap Parameters and Sequence Filtering**: This includes parameters like `dustmasker`, `windowmasker`, and the `best-hit` filtering algorithm, which help in identifying low-complexity regions or overly represented sequences that may not be of interest. These filters ensure efficient searching by managing sequence complexity and relevance.
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is designed to organize information related to human disorders and other phenotypes with a genetic component. A MedGen record includes several components:
#
# 1. **Definitions**: Each concept in MedGen has a single definition displayed in search summaries, prioritized from sources like GTR®, SNOMED CT®, or UMLS®.
#
# 2. **Identifiers**: Includes identifiers from source databases for attribution and interactive searching. Alternative IDs from the Human Phenotype Ontology (HPO) are also maintained.
#
# 3. **Gene-Phenotype Relationships**: Reports causative genes linked to a disease concept, with links to NCBI’s Gene database and OMIM®.
#
# 4. **Cytogenetic Locations**: Information on cytogenetic locations based on contributing gene disorders from ClinVar.
#
# 5. **Inter-concept Relationships**: Includes diagnosis-clinical feature relationships and hierarchies such as clinical features, computed disorders from parent-child relationships, and curated disorders by GTR®/ClinVar staff.
#
# 6. **Published Literature**: Provides information through curation of professional guidelines, aggregation of publications from ClinVar and GTR®, and PubMed queries for related literature.
#
# 7. **Dataflow**: Data are acquired both programmatically and manually, organized around a defined concept with unique identifiers.
#
# 8. **Additional Attributes**: Includes clinical findings, causative genetic variants, genes, available tests, molecular resources, professional guidelines, original/review literature, consumer resources, clinical trials, and related web links.
#
# MedGen serves as a centralized access point for diverse types of content related to medical genetics.
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The provided context does not include specific details about the dimensions of the fixed amount of computation per cell of a path graph in standard dynamic programming algorithms for pairwise sequence alignment. Therefore, I don't know the answer based on this information.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The alignment of a simple sequence with a pattern embodied by a position-specific score matrix is almost completely analogous to the alignment of two simple sequences. The main difference lies in how scores are determined: for aligning a letter with a pattern position, the score comes from the position-specific score matrix itself rather than a substitution matrix used in standard pairwise alignments.
#
# For proteins, instead of using a fixed 20 × 20 substitution matrix, a position-specific matrix is employed, which has dimensions L × 20 (where L is the length of the query sequence). Position-specific gap costs may also be defined. The process can involve finding best global or local alignments similar to those used in standard BLAST operations.
#
# Position-specific matrices gain power from improved probability estimation of amino acids at various positions and precise motif boundary definitions, reducing search space size and noise. However, constructing these matrices often involves complex decisions, with each matrix having a length equal to the original query sequence when searching databases. This approach seeks local alignments without deriving position-specific gap scores, using default BLAST gap scores instead for simplicity and ease of estimating statistical significance.
# ***********

# %%
# changed rag context question
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model gemma3:12b --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: gemma3:12b
# Q: Which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria to design the new BLAST code are a nucleotide match reward and a nucleotide mismatch penalty. The values depend on the task. For example, for the MEGABLAST task, the reward is 1 and the penalty is -2. For BLASTN and DISCONTIGUOUS MEGABLAST, the reward is 2 and the penalty is -3.
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is simple: once a concept is identified, categories of information related to that concept are identified and reported.
#
# A MedGen record has several components including:
#
# *   Author Affiliation
# *   Definition or description
# *   Clinical findings
# *   Causative genetic variants and genes
# *   Clinical and research tests
# *   Molecular resources
# *   Professional guidelines
# *   Literature
# *   Consumer resources
# *   Clinical trials
# *   Web links
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The context does not provide the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The alignment of a simple sequence with a pattern embodied by a position-specific score matrix is almost completely analogous to the alignment of two simple sequences. The only real difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix.
# ***********

# %%
# !ollama run llama3.3:70b "Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment"
# Out:
# ⠋ ⠹ ⠸ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠸ ⠼ ⠴ ⠦ ⠧ ⠧ ⠇ ⠏ ⠋ ⠹ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠏ ⠙ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ ⠦ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ ⠼ ⠼ ⠴ ⠧ ⠧ ⠇ ⠏ ⠙ ⠙ ⠸ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠹ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠹ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠋ ⠋ ⠹ ⠹ ⠸ ⠴ ⠴ ⠦ ⠇ ⠏ ⠏ ⠋ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠸ ⠼ ⠴ ⠴ ⠧ ⠧ ⠇ ⠋ ⠙ ⠙ ⠹ ⠼ ⠼ ⠴ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠸ ⠸ ⠼ ⠴ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠼ ⠴ ⠦ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ ⠴ ⠦ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠼ ⠴ ⠦ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠸ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠋ ⠋ ⠹ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠹ ⠼ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠹ ⠸ ⠼ ⠼ ⠦ ⠧ ⠧ ⠏ ⠏ ⠙ ⠹ ⠸ ⠸ ⠼ ⠦ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠼ ⠼ ⠦ ⠦ ⠇ ⠏ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠹ ⠸ ⠼ ⠴ ⠦ ⠦ ⠧ ⠇ ⠋ ⠋ ⠙ ⠸ ⠸ ⠼ ⠦ ⠦ ⠧ ⠏ ⠋ ⠙ ⠙ ⠸ ⠸ ⠴ ⠦ ⠦ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠼ ⠼ ⠦ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠼ ⠼ ⠦ ⠦ ⠇ ⠏ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠧ ⠧ ⠇ ⠏ ⠋ ⠹ ⠹ ⠼ ⠼ ⠴ ⠧ ⠇ ⠏ ⠋ ⠋ ⠙ ⠸ ⠼ ⠼ ⠴ ⠦ ⠇ ⠏ ⠏ ⠋ ⠹ ⠸ ⠼ ⠼ ⠦ ⠦ ⠇ ⠇ ⠋ ⠋ ⠹ ⠹ ⠼ ⠴ ⠴ ⠧ ⠇ ⠇ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠏ ⠋ ⠙ ⠹ ⠹ ⠸ ⠼ ⠴ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠇ ⠏ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠋ ⠙ ⠙ ⠹ ⠸ ⠴ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠙ ⠹ ⠼ ⠴ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠙ ⠸ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠋ ⠋ ⠹ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠙ ⠸ ⠸ ⠼ ⠴ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠧ ⠇ ⠇ ⠋ ⠋ ⠹ ⠹ ⠼ ⠴ ⠦ ⠦ ⠧ ⠇ ⠋ ⠋ ⠙ ⠸ ⠸ ⠴ ⠦ ⠧ ⠇ ⠇ ⠏ ⠋ ⠹ ⠸ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠋ ⠋ ⠙ ⠸ ⠼ ⠼ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠸ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ A very specific question!
#
# In the standard dynamic programming algorithms for pairwise sequence alignment, such as Needleman-Wunsch or Smith-Waterman, the computation per cell of a path graph can be broken down into several dimensions:
#
# 1. **Sequence indices**: The algorithm iterates over two sequences, typically represented as strings or arrays of characters. Each cell in the path graph corresponds to a pair of sequence indices, `(i, j)`, where `i` is an index into the first sequence and `j` is an index into the second sequence.
# 2. **Scoring functions**: The algorithm uses scoring functions to evaluate the similarity between the two sequences at each position. These scoring functions typically depend on the type of match (e.g., exact match, mismatch, gap), and can be represented as a set of weights or matrices. Common scoring functions include:
# 	* Match/mismatch scores (`match` and `mismatch`)
# 	* Gap penalties (`gap_open` and `gap_extend`)
# 3. **Alignment types**: The algorithm considers different types of alignments at each position, including:
# 	* **Match** (or **diagonal**): a match between the two sequences
# 	* **Delete** (or **vertical**): a deletion in the first sequence
# 	* **Insert** (or **horizontal**): an insertion in the second sequence
# 4. **Scores**: The algorithm computes scores for each cell in the path graph, which represent the best alignment score up to that point. These scores are typically represented as a 2D array or matrix, where each element `(i, j)` contains the score for the optimal alignment between the first `i` characters of the first sequence and the first `j` characters of the second sequence.
#
# In terms of dimensions, we can think of the computation per cell as having the following structure:
#
# * **Input dimensions**:
# 	+ Sequence indices: 2 (i, j)
# 	+ Scoring functions: typically a small set of weights or matrices (e.g., 3-5 scoring functions)
# * **Output dimension**:
# 	+ Score: 1 (the optimal alignment score for the current cell)
#
# So, in total, we can think of the computation per cell as having around 4-6 dimensions:
#
# * 2 sequence indices (i, j)
# * 2-4 scoring function weights or matrices
# * 1 output score dimension
#
# Keep in mind that these dimensions are not necessarily independent, and the algorithm's computations involve interactions between them. However, this breakdown should give you a sense of the complexity involved in computing the fixed amount of computation per cell in pairwise sequence alignment algorithms.

# %%
# !ollama run llama3.2:3b "Which are the 2 most important criteria to design the new BLAST code?"
# Out:
# The BLAST (Basic Local Alignment Search Tool) algorithm is a widely used bioinformatics tool for comparing a query sequence to a database of known sequences. When designing a new version of BLAST, there are several factors to consider, but here are two of the most important criteria:
#
# 1. **Sensitivity and Specificity**: The primary goal of any alignment algorithm like BLAST is to accurately identify matches between sequences while minimizing false positives (non-actual matches) and false negatives (actual matches missed). Designing a new BLAST code should prioritize sensitivity and specificity, which can be achieved by:
# 	* Improving the scoring matrix and gap penalties to better capture short sequences and motifs.
# 	* Enhancing the Smith-Waterman algorithm's local alignment capabilities to detect smaller patterns and similarities.
# 	* Implementing more efficient algorithms for handling large datasets and multiple query sequences simultaneously.
# 2. **Computational Efficiency**: BLAST is a computationally intensive task, especially when dealing with large databases and high-throughput sequencing data. The new design should prioritize computational efficiency by:
# 	* Optimizing the algorithm's time complexity to reduce processing times for both query and database sequences.
# 	* Implementing parallelization techniques to take advantage of multi-core processors or distributed computing architectures.
# 	* Selecting efficient data structures and algorithms for indexing, querying, and result sorting.
#
# By focusing on these two criteria, you can create a new BLAST code that balances accuracy with computational efficiency, enabling researchers to efficiently analyze large-scale biological datasets.

# %%
# !ollama run llama3.2:3b "What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences"
# Out:
# When aligning a simple sequence (a short DNA or protein sequence) with a pattern embodied by a position-specific score matrix, also known as local alignment, the goal is to find the best match between the two sequences. This type of alignment is typically performed using algorithms such as Smith-Waterman or Needleman-Wunsch.
#
# In contrast, when aligning two simple sequences together (i.e., comparing two sequences against each other), this is known as a global alignment problem. The main difference between these two types of alignments is the way they approach finding the best match.
#
# Here are some key differences:
#
# **Local Alignment:**
#
# * Focuses on finding a local match between the sequence and the pattern, rather than an overall similarity.
# * Typically used for identifying short motifs or patterns within a longer sequence.
# * The alignment is usually scored based on a score matrix that reflects the likelihood of each residue being part of the pattern (e.g., a matrix with high scores for certain residues).
# * The alignment may not be unique; multiple local alignments can exist between the same sequence and pattern.
#
# **Global Alignment:**
#
# * Aims to find an optimal match between two sequences, taking into account their overall similarity.
# * Typically used for comparing two sequences against each other, such as identifying similarities or differences between two genes.
# * The alignment is scored based on a global score matrix that reflects the likelihood of each pair of residues being part of the match.
# * Global alignments are usually unique; there is only one optimal alignment.
#
# To illustrate the difference, consider an example:
#
# Suppose we want to align the DNA sequence "ATCG" with a pattern embodied by a position-specific score matrix (e.g., a 3x4 matrix where each row represents a residue and each column represents a nucleotide). The local alignment algorithm would focus on finding a short match between the sequence and the pattern, such as the motif "A" or "T".
#
# On the other hand, if we want to align two DNA sequences "ATCG" and "ACGT", a global alignment algorithm would look for an optimal match between the two sequences, taking into account their overall similarity.
#
# In summary, local alignment is used to identify short patterns within a sequence, while global alignment is used to compare two sequences against each other, finding an optimal match based on their overall similarity.

# %%
# !ollama run llama3.2:3b "What is the MedGen data model? What are the components of a MedGen record?"
# Out:
# ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠋ ⠙ ⠙ ⠹ ⠸ ⠴ ⠴ ⠧ ⠇ ⠇ ⠏ ⠙ ⠙ ⠹ ⠼ ⠼ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠧ ⠏ ⠋ ⠋ ⠙ ⠸ ⠼ ⠼ ⠴ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ The MedGen (Medical Genetic) database is a comprehensive online repository of human genes and their relationships to diseases, disorders, traits, and other conditions. The MedGen data model is a standardized way of representing gene-related information in a structured format.
#
# A MedGen record consists of several key components:
#
# 1. **Gene**:
# 	* Gene symbol (e.g., BRCA1)
# 	* Gene name
# 	* Organism (human, mouse, rat, etc.)
# 2. **Inheritance Pattern**:
# 	* Inherited pattern (autosomal dominant, autosomal recessive, X-linked dominant, etc.)
# 	* Probability of inheritance
# 3. **Disease/Disorder Relationship**:
# 	* Disease or disorder name
# 	* Relationship type (e.g., causative, associative, diagnostic)
# 4. **Trait**:
# 	* Trait description (e.g., height, eye color)
# 5. **Genotype**:
# 	* Allele information (e.g., variant names, frequencies)
# 6. **Phenotype**:
# 	* Phenotype description
# 7. **Population**:
# 	* Population(s) studied
# 8. **Publication(s)**:
# 	* List of references to studies supporting the gene-disease relationship
#
# These components are combined to provide a comprehensive and standardized representation of gene-related information, facilitating research, clinical decision-making, and personalized medicine.
#
# The MedGen data model is maintained by the National Center for Biotechnology Information (NCBI) and is widely used in genetic medicine and biomedical research.

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/testRAG.py --v_model mxbai-embed-large --LLM_model phi4 --db_dir /content/testdata1/ --db_name blastdb
# Out:
# Vector model: mxbai-embed-large
# LLM: phi4
# Q: Which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria for designing the new BLAST code are:
#
# 1. **Scoring Parameters**: This includes defining reward and penalty values for nucleotide matches and mismatches. Different tasks (e.g., MEGABLAST vs. BLASTN) have different scoring parameters optimized for specific scenarios.
#
# 2. **Task Optimization**: The concept of a "task" allows the software to optimize searches by adjusting command-line arguments, such as word size and default scoring parameters, according to the task's requirements (e.g., high sensitivity vs. speed).
# ***********
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is simple, focusing on identifying a concept related to human disorders or phenotypes and categorizing associated information into descriptors, links to other databases, and concept-concept relationships.
#
# Components of a MedGen record include:
# - Definitions or descriptions for concepts.
# - Clinical findings and causative genetic variants and genes.
# - Links to clinical and research tests, molecular resources, professional guidelines.
# - Related literature, consumer resources, clinical trials, and web links.
# - Unique identifier (Concept ID) and semantic type.
# ***********
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The dimensions of the fixed amount of computation per cell in a path graph for pairwise sequence alignment using standard dynamic programming algorithms are typically \(O(1)\). This is because each cell involves constant-time operations related to calculating scores based on neighboring cells and substitution matrices. The space complexity, however, can be optimized from \(O(m \times n)\) (where \(m\) and \(n\) are the lengths of the sequences being aligned) to \(O(\min(m, n))\) using techniques like Hirschberg's algorithm or banded alignment.
# ***********
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The alignment of a simple sequence with a pattern embodied by a position-specific score matrix is similar to aligning two simple sequences, but differs in that:
#
# 1. The score for aligning a letter with a pattern position comes from the position-specific score matrix rather than a general substitution matrix.
# 2. For proteins, this involves using a position-specific matrix of dimension L × 20 (where L is the query length) instead of a standard 20 × 20 substitution matrix.
# 3. Position-specific gap costs can be defined, but are not always used in the described implementation.
#
# These differences allow for improved sensitivity and precise motif boundary definition while maintaining some computational efficiency by treating gaps similarly to traditional sequence comparisons.
# ***********

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/demo_colab_2.py
# Out:
# Vector model: nomic-embed-text
# Q: Which are the 2 most important criteria to design the new BLAST code?
# Two important criteria for designing a new BLAST code are:
#
# 1. Speed: The new design should aim to improve the speed of the search while maintaining or improving its sensitivity.
# 2. Sensitivity: The new design should also consider increasing the sensitivity of the search to weak similarities, which can be challenging due to the tradeoff with speed.
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model has a simple structure, where categories of information related to a concept are identified and reported. A MedGen record has several important components:
#
# 1. Author Affiliation
# 2. Definition (with attribution and link to source)
# 3. Identifiers from source databases
# 4. Gene-phenotype relationships
# 5. Cytogenetic locations
# 6. Inter-concept relationships
# 7. Published literature
# 8. Dataflow (includes aggregation, curation, and querying)
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment are:
#
# - 3 (for scoring matrix)
# - 4 (for number of occurrences)
#
# These cells account for approximately 2766 out of the total cells explored during a reverse extension.
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# What is the main difference between aligning a simple sequence with a pattern embodied by a position-specific score matrix and aligning two simple sequences?
#
# Alignment of a simple sequence with a pattern embodies by a position-specific score matrix typically involves using the matrix to guide the alignment, but still considering gaps as part of the alignment.
#
# Alignment of two simple sequences does not consider gaps, since both sequences are already defined.

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/demo_colab_2.py
# Out:
# Vector model: mxbai-embed-large
# Q: Which are the 2 most important criteria to design the new BLAST code?
# The two most important criteria to design the new BLAST code are:
# 1. Reward for a nucleotide match
# 2. Penalty for a nucleotide mismatch.
#
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is simple, categorizing information related to a concept into descriptors, links to other databases, or concept-concept relationships. A MedGen record has several components including definition, clinical findings, causative genetic variants, genes, available tests, molecular resources, professional guidelines, literature, and Web links to other NCBI and non-NCBI resources.
#
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The dimensions are not explicitly stated in the provided context.
#
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix.

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/demo_colab_2.py
# Out:
# Vector model: mxbai-embed-large
# Q: Which are the 2 most important criteria to design the new BLAST code?
# Based on general knowledge of software design principles and user experience, two important criteria for designing the new BLAST code are:
#
# 1. **User Interface**: A user-friendly interface that allows users to easily input parameters, select options, and view results without requiring extensive technical expertise.
# 2. **Flexibility and Customization**: The ability to allow users to save and reuse custom command-line options, strategy files, or other configurations to accommodate their specific research needs and workflows.
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model is simple, with a record consisting of several components:
#
# 1. Author Affiliation
# 2. Definition or description
# 3. Clinical findings
# 4. Causative genetic variants and genes
# 5. Available clinical and research tests
# 6. Molecular resources
# 7. Professional guidelines
# 8. Original and review literature
# 9. Consumer resources
# 10. Clinical trials
# 11. Web links to other related NCBI and non-NCBI resources.
#
# These components provide a structured framework for organizing information about human disorders and phenotypes, allowing users to access and synthesize relevant data.
# Q: Which are the dimensions of the fixed amount of computation per cell of a path graph in the standard dynamic programming algorithms for pairwise sequence alignment
# The standard dynamic programming algorithms for pairwise sequence alignment have a fixed amount of computation per cell in the path graph, which is equal to:
#
# - 2 (for gapped alignments)
# - 1 (for ungapped alignments)
#
# Note: These values are specific to the BLAST algorithm and may not be applicable to other pairwise sequence alignment algorithms.
# Q: What is the difference between the alignment of a simple sequence with a pattern embodied by a position-specific score matrix to the alignment of two simple sequences
# The alignment of a simple sequence with a pattern embodied by a position-specific score matrix is almost completely analogousto the alignment of two simple sequences. The only real difference is that the score for aligning a letter with a pattern position is given by the matrix itself, rather than with reference to a substitution matrix.
#
# For proteins, a query of length L and a substitution matrix of dimension 20 ×20 are replaced by a position-specific matrix of dimension L ×20. Position-specific gap costs may be defined as well.
#
# The main difference between the two alignments is that the position-specific score matrix takes into account the probabilities of amino acids occurring at various pattern positions, leading to a more sensitive scoring system.

# %%
# !/content/miniforge3/envs/ml/bin/python ai/scripts/demo_colab.py
# Out:
# Vector model: nomic-embed-text
# Q: What is the MedGen data model? What are the components of a MedGen record?
# The MedGen data model consists of categories of information that relate to a specific concept, including:
#
# 1. Author Affiliation
# 2. Identifiers from source databases
# 3. Gene-phenotype relationships
# 4. Cytogenetic locations
# 5. Inter-concept relationships
# 6. Published literature
# Traceback (most recent call last):
#   File "/content/ai/scripts/demo_colab.py", line 40, in <module>
#     xxxxxxxxxx
# NameError: name 'xxxxxxxxxx' is not defined

# %%
# see data sources

# %%
# load from URLs

# %%
# check how many documents there are in the DB

# %%
# !ollama list
# Out:
# NAME                       ID              SIZE      MODIFIED
# llama3.2:3b                a80c4f17acd5    2.0 GB    10 seconds ago
# nomic-embed-text:latest    0a109f422b47    274 MB    3 hours ago

# %%
# !/content/miniforge3/envs/ml/bin/python ai/queryDBColab.py
# Out:
# Vector model: nomic-embed-text
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_get_embeddings', '_load_or_create_vector_db', '_process_and_add', 'chroma_db_dir', 'clear_database', 'collection_name', 'count_docs', 'delete_source', 'load_data', 'load_html', 'load_pdf', 'load_url', 'model', 'peek', 'query', 'query_sources', 'show_sources', 'vector_db']
# NewDB
# {'ids': [], 'embeddings': [], 'metadatas': [], 'documents': [], 'uris': None, 'data': None, 'included': ['embeddings', 'metadatas', 'documents']}
# **

# %% [markdown]
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_get_embeddings', '_load_or_create_vector_db', '_process_and_add', 'chroma_db_dir', 'clear_database', 'collection_name', 'count_docs', 'delete_source', 'load_data', 'load_html', 'load_pdf', 'load_url', 'model', 'peek', 'query', 'query_sources', 'show_sources', 'vector_db']

# %% [markdown]
# # Advanced options

# %%
import tempfile


# @title Adjust model parameters
# @markdown To adjust model parameter in Ollama, you need to create a derived model. This cell will generate a derived model.

# @markdown **Warning**: Not all model support all parameter. Using wrong parameters may generate a degraded model.

# @markdown ---
# @markdown Select a model to change (input model):
LLM_model = "gemma3:4b" # @param ["phi4", "gemma3:4b", "gemma3:12b", "llama4", "llama3.3:70b", "llama3.2:3b", "llama3.1:8b"]
# @markdown Enter new model name:
new_model = "genma3T07" # @param {type:"string"}
# @markdown Enter new template file name (if blank will use a random name):
tpl_fn = "" # @param {type:"string","placeholder":"Modelfile"}

if tpl_fn == "":
    # make a random filename
    tpl_fn = tempfile.mktemp(suffix='.txt')

# @markdown Temperature:  Increasing the temperature will make the model answer more creatively.
temp = 0.7 # @param {"type":"slider","min":0,"max":1,"step":0.05}
# @markdown num_ctx: Sets the size of the context window used to generate the next token
num_ctx = 4018 # @param {"type":"slider","min":1024,"max":18000,"step":1}
# @markdown seed: Sets the size of the context window used to generate the next token
seed = 4482 # @param {"type":"slider","min":0,"max":10000,"step":1}
# @markdown Maximum number of tokens to predict when generating text. (Default: -1, infinite generation)
num_predict = 4790 # @param {"type":"slider","min":-1,"max":10000,"step":1}
# @markdown Top K: Reduces the probability of generating nonsense. A higher value will give more diverse answers, while a lower value will be more conservative.
top_k = 20 # @param {"type":"slider","min":1,"max":100,"step":1}
# @markdown Top P: Works together with top-k. A higher value will lead to more diverse text, while a lower value will generate more focused and conservative text.
top_p = 0.47 # @param {"type":"slider","min":0,"max":1,"step":0.01}
# @markdown Min P: Alternative to the top_p, and aims to ensure a balance of quality and variety. The parameter p represents the minimum probability for a token to be considered, relative to the probability of the most likely token. For example, with p=0.05 and the most likely token having a probability of 0.9, logits with a value less than 0.045 are filtered out.
min_p = 0 # @param {"type":"slider","min":0,"max":1,"step":0.01}


# @markdown ---

# @markdown [More about model parameters](https://github.com/ollama/ollama/blob/main/docs/modelfile.md#valid-parameters-and-values)

# @markdown ---
model_file = f"""FROM {LLM_model}
PARAMETER temperature {temp}
PARAMETER num_ctx {num_ctx}
PARAMETER seed {seed}
PARAMETER num_predict {num_predict}
PARAMETER top_k {top_k}
PARAMETER top_p {top_p}
PARAMETER min_p {min_p}
"""

#mdir = "/content/miniforge3/envs/ml/lib/python3.10/site-packages/ollama/models/"

with open(f"{tpl_fn}", "w") as f:
    f.write(model_file)


# !ollama create {new_model} -f {tpl_fn}
# Out:
# gathering model components
# using existing layer sha256:aeda25e63ebd698fab8638ffb778e68bed908b960d39d0becc650fa981609d25
# using existing layer sha256:e0a42594d802e5d31cdc786deb4823edb8adff66094d49de8fffe976d753e348
# using existing layer sha256:dd084c7d92a3c1c14cc09ae77153b903fd2024b64a100a0cc8ec9316063d2dbc
# creating new layer sha256:5c713b945982e66464f922de12120c66e8453df5ea5bfa57c16b629e7c6d7cd6
# writing manifest
# success

# %%
# @title Run a query against the LLM
# @markdown This query will be done without using RAG

# @markdown ---
# @markdown ### Enter a prompt:
query = "What is the MedGen data model? Provide a list of data elements aggregated in MedGen" # @param {type:"string"}
# @markdown ---

# !ollama run {new_model} {query}
# Out:
# Okay, let's break down the MedGen data model and the data elements it aggregates. MedGen is a unique and powerful research database developed by the U.S. Department of Veterans Affairs (VA) to support clinical research. It's not a standard database, and its data model is quite complex, reflecting the VA's extensive clinical data collection practices.
#
# **Core Principles of the MedGen Data Model**
#
# The MedGen data model is built around the concept of **Clinical Research Data Objects (CRDOs)**.  Instead of a traditional relational database, MedGen organizes data around these CRDOs, which represent specific pieces of clinical information that researchers are interested in.  Here's a breakdown of the key aspects:
#
# * **CRDOs (Clinical Research Data Objects):** These are the fundamental building blocks. They represent a specific clinical event or measurement. Examples include:
#     * **Medication Events:**  Specific instances of medication administration.
#     * **Laboratory Measurements:**  Results from blood tests, urine tests, etc.
#     * **Imaging Studies:**  Results from X-rays, MRIs, CT scans, etc.
#     * **Clinical Assessments:**  Scores from questionnaires, physical exams, or other clinical evaluations.
#     * **Procedures:**  Specific medical procedures performed.
#     * **Vital Signs:**  Measurements like blood pressure, heart rate, temperature.
# * **Hierarchical Structure:** MedGen uses a hierarchical structure to organize CRDOs.  Higher-level CRDOs (like "Medication Event") can have multiple lower-level CRDOs associated with them (e.g., a medication event might have multiple doses, each with specific attributes).
# * **Temporal Dimension:**  A critical aspect is the strong temporal dimension. MedGen meticulously tracks *when* events occurred, allowing researchers to analyze trends over time.
# * **Data Quality & Standardization:** The VA has invested heavily in data quality and standardization.  MedGen uses standardized vocabularies and coding systems (e.g., SNOMED CT, RxNorm, LOINC) to ensure consistency and interoperability.
#
#
# **List of Data Elements Aggregated in MedGen**
#
# This is a categorized list of the types of data elements that MedGen aggregates.  It's not exhaustive, and the specific elements available will vary depending on the data collection practices at the individual VA facility.
#
# **1. Patient Demographics & Clinical Information:**
#
# * **Patient Identifier:** Unique VA patient identifier.
# * **Age:** Patient's age at the time of the event.
# * **Sex:** Patient's sex.
# * **Race/Ethnicity:** Patient's race and ethnicity.
# * **Insurance Information:**  VA insurance type.
# * **Service History:** Military service information.
#
# **2. Medication Data:**
#
# * **Medication Identifier:**  Unique identifier for the medication (e.g., RxNorm ID).
# * **Dosage:** Amount of medication administered.
# * **Route:**  How the medication was administered (e.g., oral, intravenous).
# * **Frequency:** How often the medication was administered.
# * **Duration:**  The length of time the medication was administered.
# * **Prescriber Identifier:**  Identifier for the physician who prescribed the medication.
# * **Medication Order Number:**  Unique identifier for the medication order.
#
# **3. Laboratory Measurements:**
#
# * **Laboratory Test Identifier:**  Unique identifier for the lab test (e.g., LOINC ID).
# * **Result Value:** The numerical result of the lab test.
# * **Units:**  The units of measurement for the result (e.g., mg/dL, mmol/L).
# * **Reference Range:**  The normal range for the result.
# * **Test Date:**  The date the lab test was performed.
#
# **4. Imaging Studies:**
#
# * **Imaging Study Identifier:** Unique identifier for the imaging study (e.g., DICOM ID).
# * **Modality:** Type of imaging study (e.g., X-ray, MRI, CT).
# * **Body Part Examined:** The anatomical region imaged.
# * **Image File Identifier:**  Unique identifier for the image file.
# * **Radiologist Identifier:** Identifier for the radiologist who interpreted the image.
#
# **5. Clinical Assessments & Procedures:**
#
# * **Assessment Identifier:** Unique identifier for the assessment (e.g., SNOMED CT ID).
# * **Score Value:** The score obtained from the assessment.
# * **Assessment Date:** The date the assessment was performed.
# * **Procedure Identifier:** Unique identifier for the procedure (e.g., CPT code).
# * **Procedure Date:** The date the procedure was performed.
#
# **6. Vital Signs:**
#
# * **Vital Sign Identifier:** Unique identifier for the vital sign (e.g., LOINC ID).
# * **Value:** The measured value of the vital sign.
# * **Units:** The units of measurement for the vital sign.
# * **Measurement Date:** The date the vital sign was measured.
#
#
# **Important Notes:**
#
# * **Data Quality is Paramount:** The VA has invested heavily in data quality control, but issues can still arise.
# * **Access Restrictions:** Access to MedGen is generally restricted to authorized researchers.
# * **Dynamic Data:** MedGen is a living database, constantly updated with new data.
#
# **Resources for More Information:**
#
# * **VA Research and Development - MedGen:** [https://www.va.gov/research/data-resources/medgen/](https://www.va.gov/research/data-resources/medgen/)
# * **VA Research Databases Portal:** [https://www.va.gov/research/data-resources/](https://www.va.gov/research/data-resources/)
#
#
# Do you want me to delve deeper into a specific aspect of the MedGen data model, such as:
#
# *   The CRDO hierarchy in more detail?
# *   The standardization efforts and vocabularies used?
# *   How MedGen is used in research?

# %%
# @title Run a query against the LLM
# @markdown This query will be done without using RAG

# @markdown ---
# @markdown ### Enter a prompt:
query = "What is the MedGen data model? Provide a list of data elements aggregated in MedGen" # @param {type:"string"}
# @markdown ---
print(f"Model name: {new_model}")
# !ollama run {new_model} {query}
# Out:
# Model name: genma3T0
# ⠙ Okay, let's break down the MedGen data model and the data elements it aggregates. MedGen is a unique and powerful resource, and its data model is a key part of its value.
#
# **What is the MedGen Data Model?**
#
# MedGen is a comprehensive, curated database of biomedical literature, primarily focused on the areas of:
#
# *   **Neuroscience:**  This is its core strength, encompassing neurology, psychiatry, neurobiology, and related fields.
# *   **Pharmacology & Toxicology:**  A significant portion of the data relates to drug effects, mechanisms of action, and adverse reactions.
# *   **Genetics & Genomics:**  Data on gene function, mutations, and genetic disorders.
#
# The data model isn't a traditional relational database in the sense of tables with strict foreign keys. Instead, it’s a **graph-based knowledge representation**. This means information is linked together based on semantic relationships, rather than just stored in separate tables. This allows for incredibly complex queries and inferences.
#
# **Key Characteristics of the MedGen Data Model:**
#
# *   **Nodes:** The fundamental building blocks are "nodes," which represent concepts, entities, or pieces of information. Examples include:
#     *   Genes
#     *   Drugs
#     *   Diseases
#     *   Proteins
#     *   Chemicals
#     *   Biological Pathways
#     *   Clinical Trials
#     *   Publications
# *   **Edges:**  "Edges" represent the relationships between these nodes. These relationships are explicitly defined and labeled. Examples include:
#     *   "InteractsWith" (e.g., a drug interacts with a protein)
#     *   "Causes" (e.g., a gene causes a disease)
#     *   "AssociatedWith" (e.g., a gene is associated with a disease)
#     *   "TreatmentFor" (e.g., a drug is a treatment for a disease)
#     *   "PublishedIn" (e.g., a gene is described in a publication)
# *   **Ontology-Driven:** MedGen uses a standardized ontology (primarily the Gene Ontology - GO) to annotate nodes, ensuring consistency and enabling interoperability with other biomedical databases.
# *   **Curated and Annotated:**  The data is meticulously curated by experts, and each node is richly annotated with metadata (e.g., publication details, gene symbols, chemical names, etc.).
#
# **List of Data Elements Aggregated in MedGen (Key Categories):**
#
# Here's a breakdown of the types of data elements you'll find in MedGen, categorized for clarity:
#
# 1.  **Genes & Proteins:**
#     *   Gene Symbol (e.g., *TP53*)
#     *   Entrez Gene ID (e.g., 923)
#     *   Gene Ontology (GO) Terms (e.g., "DNA Binding")
#     *   Protein Sequence Information
#     *   Mutations Associated with the Gene
#
# 2.  **Drugs & Chemicals:**
#     *   Drug Name (e.g., "Donepezil")
#     *   Chemical Name (e.g., "N-Ethyl-5-methylpiperidin-4-carboxamide")
#     *   CAS Registry Number
#     *   Molecular Formula
#     *   Pharmacological Class
#
# 3.  **Diseases & Disorders:**
#     *   Disease Name (e.g., "Alzheimer's Disease")
#     *   Disease Ontology (DO) ID
#     *   Associated Genes and Drugs
#
# 4.  **Publications & Research Articles:**
#     *   PubMed ID (e.g., PM7313331)
#     *   Title
#     *   Authors
#     *   Abstract
#     *   Full Text (often linked)
#
# 5.  **Biological Pathways:**
#     *   Pathway Name (e.g., "MAPK Signaling Pathway")
#     *   Pathway ID (e.g., KEGG Pathway ID)
#     *   Nodes within the pathway (genes, proteins, etc.)
#
# 6.  **Clinical Trials:**
#     *   Trial Identifier (e.g., ClinicalTrials.gov ID)
#     *   Study Design
#     *   Interventions
#     *   Patient Population
#
# 7.  **Other Biological Entities:**
#     *   Receptors
#     *   Enzymes
#     *   Cell Types
#     *   Cellular Processes
#
# **Important Notes:**
#
# *   **Dynamic Data:** The MedGen database is constantly updated as new research is published.
# *   **Access:**  Access to MedGen is typically through a web interface or through APIs.
# *   **Unique Features:**  MedGen's strength lies in its ability to perform complex queries that would be difficult or impossible in traditional relational databases.  You can, for example, find all drugs that interact with a specific gene *and* are used to treat a particular disease.
#
# **Resources for More Information:**
#
# *   **MedGen Website:** [https://medgen.org/](https://medgen.org/)
# *   **Gene Ontology (GO):** [http://geneontology.org/](http://geneontology.org/)
#
# Do you want me to delve deeper into a specific aspect of the MedGen data model, such as:
#
# *   How queries are performed?
# *   The role of the ontology?
# *   How MedGen compares to other biomedical databases?

# %%
# @title Run a query against the LLM
# @markdown This query will be done without using RAG

# @markdown ---
# @markdown ### Enter a prompt:
query = "What is the MedGen data model? Provide a list of data elements aggregated in MedGen" # @param {type:"string"}
# @markdown ---
print(f"Model name: {new_model}")
# !ollama run {new_model} {query}
# Out:
# Model name: genma3T0
# ⠙ Okay, let's break down the MedGen data model and the data elements it aggregates. MedGen is a unique and powerful resource, and its data model is a key part of its value.
#
# **What is the MedGen Data Model?**
#
# MedGen is a comprehensive, curated database of biomedical literature, primarily focused on the areas of:
#
# *   **Neuroscience:**  This is its core strength, encompassing neurology, psychiatry, neurobiology, and related fields.
# *   **Pharmacology & Toxicology:**  A significant portion of the data relates to drug effects, mechanisms of action, and adverse reactions.
# *   **Genetics & Genomics:**  Data on gene function, mutations, and genetic disorders.
#
# The data model isn't a traditional relational database in the sense of tables with strict foreign keys. Instead, it’s a **graph-based knowledge representation**. This means information is linked together based on semantic relationships, rather than just stored in separate tables. This allows for incredibly complex queries and inferences.
#
# **Key Characteristics of the MedGen Data Model:**
#
# *   **Nodes:** The fundamental building blocks are "nodes," which represent concepts, entities, or pieces of information. Examples include:
#     *   Genes
#     *   Drugs
#     *   Diseases
#     *   Proteins
#     *   Chemicals
#     *   Biological Pathways
#     *   Clinical Trials
#     *   Publications
# *   **Edges:**  "Edges" represent the relationships between these nodes. These relationships are explicitly defined and labeled. Examples include:
#     *   "InteractsWith" (e.g., a drug interacts with a protein)
#     *   "Causes" (e.g., a gene causes a disease)
#     *   "AssociatedWith" (e.g., a gene is associated with a disease)
#     *   "TreatmentFor" (e.g., a drug is a treatment for a disease)
#     *   "PublishedIn" (e.g., a gene is described in a publication)
# *   **Ontology-Driven:** MedGen uses a standardized ontology (primarily the Gene Ontology - GO) to annotate nodes, ensuring consistency and enabling interoperability with other biomedical databases.
# *   **Curated and Annotated:**  The data is meticulously curated by experts, and each node is richly annotated with metadata (e.g., publication details, gene symbols, chemical names, etc.).
#
# **List of Data Elements Aggregated in MedGen (Key Categories):**
#
# Here's a breakdown of the types of data elements you'll find in MedGen, categorized for clarity:
#
# 1.  **Genes & Proteins:**
#     *   Gene Symbol (e.g., *TP53*)
#     *   Entrez Gene ID (e.g., 923)
#     *   Gene Ontology (GO) Terms (e.g., "DNA Binding")
#     *   Protein Sequence Information
#     *   Mutations Associated with the Gene
#
# 2.  **Drugs & Chemicals:**
#     *   Drug Name (e.g., "Donepezil")
#     *   Chemical Name (e.g., "N-Ethyl-5-methylpiperidin-4-carboxamide")
#     *   CAS Registry Number
#     *   Molecular Formula
#     *   Pharmacological Class
#
# 3.  **Diseases & Disorders:**
#     *   Disease Name (e.g., "Alzheimer's Disease")
#     *   Disease Ontology (DO) ID
#     *   Associated Genes and Drugs
#
# 4.  **Publications & Research Articles:**
#     *   PubMed ID (e.g., PM7313331)
#     *   Title
#     *   Authors
#     *   Abstract
#     *   Full Text (often linked)
#
# 5.  **Biological Pathways:**
#     *   Pathway Name (e.g., "MAPK Signaling Pathway")
#     *   Pathway ID (e.g., KEGG Pathway ID)
#     *   Nodes within the pathway (genes, proteins, etc.)
#
# 6.  **Clinical Trials:**
#     *   Trial Identifier (e.g., ClinicalTrials.gov ID)
#     *   Study Design
#     *   Interventions
#     *   Patient Population
#
# 7.  **Other Biological Entities:**
#     *   Receptors
#     *   Enzymes
#     *   Cell Types
#     *   Cellular Processes
#
# **Important Notes:**
#
# *   **Dynamic Data:** The MedGen database is constantly updated as new research is published.
# *   **Access:**  Access to MedGen is typically through a web interface or through APIs.
# *   **Unique Features:**  MedGen's strength lies in its ability to perform complex queries that would be difficult or impossible in traditional relational databases.  You can, for example, find all drugs that interact with a specific gene *and* are used to treat a particular disease.
#
# **Resources for More Information:**
#
# *   **MedGen Website:** [https://medgen.org/](https://medgen.org/)
# *   **Gene Ontology (GO):** [http://geneontology.org/](http://geneontology.org/)
#
# Do you want me to delve deeper into a specific aspect of the MedGen data model, such as:
#
# *   How queries are performed?
# *   The role of the ontology?
# *   How MedGen compares to other biomedical databases?

# %%
# @title (OPTIONAL) Convert your data from URLs and load the vector DB

url_file = "/content/ai/data/raw/urls/index.urls" # @param {type:"string"}
db_dir = "/content/testdata1/" # @param {type:"string"}
db_name = "blastdb" # @param {type:"string"}

pypath = "/content/miniforge3/envs/ml/bin/python"

cmd = f"{pypath} ai/scripts/addurlstodbcolab.py --db_dir {db_dir} --db_name {db_name} --v_llm {vmodel} --url_input_file {url_file}"
result = subprocess.run(cmd, shell=True, capture_output=True, text=True)

if result.returncode == 0:
    print("Command output:\n", result.stdout)
else:
    print("Error:", result.stderr)
# Out:
# Command output:
#  Vector model: nomic-embed-text
# Current documents:
# 476
# Current documents:
# 3334
# **

# %% [markdown]
# ```
# e83f45542ae3: mxbai-embed-large gemma3:4b 140s
# 9ca86cca4e06: mxbai-embed-large gemma3:12b 280s
# 5a24890401d6: mxbai-embed-large phi4 465s
# fcf1ec5d3f5a: nomic-embed-text gemma3:4b 135s
# 5a372a7f6b5f: nomic-embed-text gemma3:12b 274s
# 3473c7041527: nomic-embed-text phi4 491s
# ```
