# %%
import sys
sys.path.append("/home/tagore/repos/ai/scripts")
from preprocess_text import preprocess_text, preprocess_files
# Out:
# [nltk_data] Downloading package punkt to /home/tagore/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/tagore/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/tagore/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
input_path = '/home/tagore/repos/ai/data/processed/texts/Bookshelf_NBK279690.pdf'
output_path = '/home/tagore/repos/ai/data/processed/processed_texts/Bookshelf_NBK279690.txt'

preprocess_files(input_path, output_path)
# Out:
# Processing page_1.txt
# Preprocessed page_1.txt and saved to /home/tagore/repos/ai/data/processed/processed_texts/Bookshelf_NBK279690.txt/page_1.txt
# Combined page_10.txt with page_100.txt
# Preprocessed page_10.txt and saved to /home/tagore/repos/ai/data/processed/processed_texts/Bookshelf_NBK279690.txt/page_10.txt
# Processing page_100.txt
# Preprocessed page_100.txt and saved to /home/tagore/repos/ai/data/processed/processed_texts/Bookshelf_NBK279690.txt/page_100.txt
# Processing page_101.txt
# Preprocessed page_101.txt and saved to /home/tagore/repos/ai/data/processed/processed_texts/Bookshelf_NBK279690.txt/page_101.txt
# Processing page_102.txt
# Preprocessed page_102.txt and saved to /home/tagore/repos/ai/data/processed/processed_texts/Bookshelf_NBK279690.txt/page_102.txt
# Processing page_103.txt
# Preprocessed page_103.txt and saved to /home/tagore/repos/ai/data/processed/processed_texts/Bookshelf_NBK279690.txt/page_103.txt
# Processing page_104.txt
# ...
